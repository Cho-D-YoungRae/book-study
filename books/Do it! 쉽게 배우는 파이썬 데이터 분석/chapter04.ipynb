# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "name": ["김지훈", "이유진", "박동현", "김민지"],
    "english": [90, 80, 60, 70],
    "math": [50, 60, 100, 20]
})
df

# %%
df["english"]
# Out:
# 0    90
# 1    80
# 2    60
# 3    70
# Name: english, dtype: int64

# %%
sum(df["english"])
# Out:
# 300

# %%
url = "https://raw.githubusercontent.com/youngwoos/Doit_Python/main/Data/excel_exam.xlsx"
df_exam = pd.read_excel(url)
df_exam

# %%
len(df_exam)
# Out:
# 20

# %%
url = "https://raw.githubusercontent.com/youngwoos/Doit_Python/main/Data/excel_exam_novar.xlsx"
df_exam_novar = pd.read_excel(url, header=None)
df_exam_novar
# Out:
#    0  1   2   3   4
# 0  1  1  50  98  50
# 1  2  1  60  97  60
# 2  3  2  25  80  65
# 3  4  2  50  89  98
# 4  5  3  20  98  15
# 5  6  3  50  98  45
# 6  7  4  46  98  65
# 7  8  4  48  87  12
