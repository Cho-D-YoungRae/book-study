# %% [markdown]
# # Chapter 19. 세상에 없는 얼굴 GAN, 오토 인코더

# %%
import sys
import numpy as np
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Embedding, LSTM, Conv1D, MaxPooling1D, Activation, BatchNormalization, LeakyReLU, UpSampling2D, Reshape, Input
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.datasets import mnist, reuters, imdb
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.text import text_to_word_sequence, Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

print(f"python: {sys.version}")
print(f"numpy: {np.__version__}")
print(f"pandas: {pd.__version__}")
print(f"sklearn: {sklearn.__version__}")
print(f"matplotlib: {matplotlib.__version__}")
print(f"seaborn: {sns.__version__}")
print(f"tensorflow: {tf.__version__}")
# Out:
# python: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# numpy: 1.25.2
# pandas: 1.5.3
# sklearn: 1.2.2
# matplotlib: 3.7.1
# seaborn: 0.13.1
# tensorflow: 2.15.0

# %% [markdown]
# ## 1. 가짜 제조 공장, 생성자
#
# > DCGAN 기준
#
# 생성자(generator)는 가상의 이미지를 만들어 내는 공장
#
# 처음에는 랜덤한 픽셀 값으로 채워진 가짜 이미지로 시작해서 판별자의 판별 결과에 따라 지속적으로 업데이트하며 점차 원하는 이미지를 만들어 감
#
# 옵티마이저를 사용하는 최적화 과정이나 컴파일 과정이 없음
# > 판별과 학습이 이곳 생성자에서 일어나는 것이 아니기 때문
#
# 풀링 과정이 없는 대신 패딩 과정이 포함
#
# 배치 정규화(Batch Normalization)
#
# > 입력 데이터의 평균이 0, 분산이 1이 되도록 재배치 하는 것.
# > 다음 층으로입력될 값을 일정하게 재배치 하는 역할.
# > 이 과정을 통해 층의 개수가 늘어나도 안정적인 학습을 진행할 수 있음
#
# 생성자의 활성화 함수르논 relu, 판별자로 넘겨주기 직전에는 tanh

# %%
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

# %% [markdown]
# 판별자(discriminator)
#
# - 이 부분은 컨볼루션 신경망의 구조를 그대로 가지고와서 만들면 됨
# - 컨볼루션 신경망이란 원래 무언가를 구별하는 데 최적화된 알고리즘이기 때문에 그 목적 그대로 사용하면 되는 것
# - 주의할 점은 이 판별자는 가짜인지 진짜인지 판별만 해줄 뿐, 자기 자신이 학습을 해서는 안 된다는 것# 생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
# ginput = Input(shape=(100,))
# dis_output = discriminator(generator(ginput))
# gan = Model(ginput, dis_output)
# gan.compile(loss='binary_crossentropy', optimizer='adam')
# gan.summary()

# %%
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

# %% [markdown]
# 학습이 진행될수록 생성자가 만든 G(input) 이 실제와 너무나 가까워져서 이것으로 만든 D(G(input)) 과 실제 데이터로 만든 D(X) 를 잘 구분하지 못하게 됨
#
# 너무나 유사해진 D(G(input)) 과 D(X) 를 판별자가 더는 구별하지 못하게 되어 정확도가 0.5에 가까워질때 비로소 생성자는 자신의 역할을 다하게 되어 학습은 종료

# %%
# 생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  sequential_1 (Sequential)   (None, 28, 28, 1)         865281
#
#  sequential_3 (Sequential)   (None, 1)                 212865
#
# =================================================================
# Total params: 1078146 (4.11 MB)
# Trainable params: 852609 (3.25 MB)
# Non-trainable params: 225537 (881.00 KB)
# _________________________________________________________________

# %% [markdown]
# `train_on_batch(x, y)` 함수는 입력 값(x) 와 레이블(y)를 받아서 딱 한 번 학습을 실시해 모델을 업데이트

# %%
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터를 불러옵니다.

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트 과정은 필요 없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀 값은 0에서 255 사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1 사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  # X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          # 가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          # 판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이 부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 이 장의 주요 내용과 관련이 없어
        # 소스 코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("./gan_mnist_%d.png" % i)

gan_train(2001, 32, 200)  # 2000번 반복되고, 배치 사이즈는 32,  200번마다 결과가 저장되게 하였습니다.
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 195ms/step
# epoch:0  d_loss:0.6899  g_loss:0.4939
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 76ms/step
# epoch:1  d_loss:0.5172  g_loss:0.2053
# 1/1 [==============================] - 0s 81ms/step
# epoch:2  d_loss:0.5275  g_loss:0.0977
# 1/1 [==============================] - 0s 81ms/step
# epoch:3  d_loss:0.5063  g_loss:0.1074
# 1/1 [==============================] - 0s 78ms/step
# epoch:4  d_loss:0.4913  g_loss:0.1745
# 1/1 [==============================] - 0s 76ms/step
# epoch:5  d_loss:0.4482  g_loss:0.3359
# 1/1 [==============================] - 0s 122ms/step
# epoch:6  d_loss:0.4314  g_loss:0.5503
# 1/1 [==============================] - 0s 135ms/step
# epoch:7  d_loss:0.4158  g_loss:0.7112
# 1/1 [==============================] - 0s 127ms/step
# epoch:8  d_loss:0.4508  g_loss:0.7580
# 1/1 [==============================] - 0s 76ms/step
# epoch:9  d_loss:0.4582  g_loss:0.7698
# 1/1 [==============================] - 0s 77ms/step
# epoch:10  d_loss:0.5132  g_loss:0.7685
# 1/1 [==============================] - 0s 81ms/step
# epoch:11  d_loss:0.5325  g_loss:0.6938
# 1/1 [==============================] - 0s 75ms/step
# epoch:12  d_loss:0.5662  g_loss:0.6612
# 1/1 [==============================] - 0s 76ms/step
# epoch:13  d_loss:0.5710  g_loss:0.5414
# 1/1 [==============================] - 0s 80ms/step
# epoch:14  d_loss:0.4980  g_loss:0.4106
# 1/1 [==============================] - 0s 74ms/step
# epoch:15  d_loss:0.3987  g_loss:0.3076
# 1/1 [==============================] - 0s 77ms/step
# epoch:16  d_loss:0.3307  g_loss:0.2387
# 1/1 [==============================] - 0s 76ms/step
# epoch:17  d_loss:0.2839  g_loss:0.2009
# 1/1 [==============================] - 0s 76ms/step
# epoch:18  d_loss:0.2490  g_loss:0.1503
# 1/1 [==============================] - 0s 77ms/step
# epoch:19  d_loss:0.1839  g_loss:0.2345
# 1/1 [==============================] - 0s 79ms/step
# epoch:20  d_loss:0.1395  g_loss:0.1900
# 1/1 [==============================] - 0s 78ms/step
# epoch:21  d_loss:0.1609  g_loss:0.1689
# 1/1 [==============================] - 0s 80ms/step
# epoch:22  d_loss:0.1140  g_loss:0.2223
# 1/1 [==============================] - 0s 81ms/step
# epoch:23  d_loss:0.1151  g_loss:0.1673
# 1/1 [==============================] - 0s 104ms/step
# epoch:24  d_loss:0.1843  g_loss:0.1228
# 1/1 [==============================] - 0s 132ms/step
# epoch:25  d_loss:0.2013  g_loss:0.3164
# 1/1 [==============================] - 0s 135ms/step
# epoch:26  d_loss:0.4405  g_loss:0.1060
# 1/1 [==============================] - 0s 79ms/step
# epoch:27  d_loss:0.6252  g_loss:0.4124
# 1/1 [==============================] - 0s 80ms/step
# epoch:28  d_loss:0.7241  g_loss:0.9394
# 1/1 [==============================] - 0s 76ms/step
# epoch:29  d_loss:1.2868  g_loss:0.2361
# 1/1 [==============================] - 0s 75ms/step
# epoch:30  d_loss:1.0820  g_loss:0.3932
# 1/1 [==============================] - 0s 75ms/step
# epoch:31  d_loss:0.7343  g_loss:0.7778
# 1/1 [==============================] - 0s 84ms/step
# epoch:32  d_loss:0.6997  g_loss:0.4638
# 1/1 [==============================] - 0s 76ms/step
# epoch:33  d_loss:0.3874  g_loss:0.5788
# 1/1 [==============================] - 0s 81ms/step
# epoch:34  d_loss:0.1946  g_loss:1.2383
# 1/1 [==============================] - 0s 78ms/step
# epoch:35  d_loss:0.1411  g_loss:1.8548
# 1/1 [==============================] - 0s 80ms/step
# epoch:36  d_loss:0.1212  g_loss:2.2075
# 1/1 [==============================] - 0s 94ms/step
# epoch:37  d_loss:0.1135  g_loss:2.1157
# 1/1 [==============================] - 0s 82ms/step
# epoch:38  d_loss:0.0573  g_loss:1.8570
# 1/1 [==============================] - 0s 78ms/step
# epoch:39  d_loss:0.0863  g_loss:1.7734
# 1/1 [==============================] - 0s 77ms/step
# epoch:40  d_loss:0.1336  g_loss:1.9277
# 1/1 [==============================] - 0s 81ms/step
# epoch:41  d_loss:0.1565  g_loss:2.6671
# 1/1 [==============================] - 0s 92ms/step
# epoch:42  d_loss:0.2835  g_loss:2.4089
# 1/1 [==============================] - 0s 132ms/step
# epoch:43  d_loss:0.4352  g_loss:2.1695
# 1/1 [==============================] - 0s 144ms/step
# epoch:44  d_loss:0.6871  g_loss:2.0481
# 1/1 [==============================] - 0s 132ms/step
# epoch:45  d_loss:0.6700  g_loss:2.5284
# 1/1 [==============================] - 0s 80ms/step
# epoch:46  d_loss:1.1237  g_loss:2.0779
# 1/1 [==============================] - 0s 94ms/step
# epoch:47  d_loss:0.9536  g_loss:1.5495
# 1/1 [==============================] - 0s 78ms/step
# epoch:48  d_loss:1.0216  g_loss:2.0412
# 1/1 [==============================] - 0s 77ms/step
# epoch:49  d_loss:0.6666  g_loss:2.0946
# 1/1 [==============================] - 0s 79ms/step
# epoch:50  d_loss:0.7792  g_loss:2.1459
# 1/1 [==============================] - 0s 82ms/step
# epoch:51  d_loss:1.0892  g_loss:1.4141
# 1/1 [==============================] - 0s 80ms/step
# epoch:52  d_loss:0.9742  g_loss:1.1688
# 1/1 [==============================] - 0s 76ms/step
# epoch:53  d_loss:0.6891  g_loss:1.3662
# 1/1 [==============================] - 0s 79ms/step
# epoch:54  d_loss:0.7891  g_loss:1.4732
# 1/1 [==============================] - 0s 75ms/step
# epoch:55  d_loss:0.6264  g_loss:1.5502
# 1/1 [==============================] - 0s 77ms/step
# epoch:56  d_loss:0.6272  g_loss:1.3546
# 1/1 [==============================] - 0s 77ms/step
# epoch:57  d_loss:0.6106  g_loss:1.3256
# 1/1 [==============================] - 0s 81ms/step
# epoch:58  d_loss:0.5697  g_loss:1.2468
# 1/1 [==============================] - 0s 78ms/step
# epoch:59  d_loss:0.5514  g_loss:1.1852
# 1/1 [==============================] - 0s 76ms/step
# epoch:60  d_loss:0.4929  g_loss:1.3466
# 1/1 [==============================] - 0s 104ms/step
# epoch:61  d_loss:0.3931  g_loss:1.4502
# 1/1 [==============================] - 0s 142ms/step
# epoch:62  d_loss:0.3949  g_loss:1.5759
# 1/1 [==============================] - 0s 177ms/step
# epoch:63  d_loss:0.3119  g_loss:1.5993
# 1/1 [==============================] - 0s 163ms/step
# epoch:64  d_loss:0.3398  g_loss:1.6357
# 1/1 [==============================] - 0s 130ms/step
# epoch:65  d_loss:0.2891  g_loss:1.5882
# 1/1 [==============================] - 0s 82ms/step
# epoch:66  d_loss:0.2751  g_loss:1.6628
# 1/1 [==============================] - 0s 79ms/step
# epoch:67  d_loss:0.2289  g_loss:1.5734
# 1/1 [==============================] - 0s 81ms/step
# epoch:68  d_loss:0.1905  g_loss:1.6224
# 1/1 [==============================] - 0s 76ms/step
# epoch:69  d_loss:0.2536  g_loss:1.6675
# 1/1 [==============================] - 0s 81ms/step
# epoch:70  d_loss:0.1790  g_loss:1.5409
# 1/1 [==============================] - 0s 80ms/step
# epoch:71  d_loss:0.1380  g_loss:1.7520
# 1/1 [==============================] - 0s 82ms/step
# epoch:72  d_loss:0.3104  g_loss:1.7556
# 1/1 [==============================] - 0s 77ms/step
# epoch:73  d_loss:0.2287  g_loss:1.3221
# 1/1 [==============================] - 0s 78ms/step
# epoch:74  d_loss:0.1964  g_loss:1.0710
# 1/1 [==============================] - 0s 80ms/step
# epoch:75  d_loss:0.3032  g_loss:1.1380
# 1/1 [==============================] - 0s 83ms/step
# epoch:76  d_loss:0.3011  g_loss:0.9043
# 1/1 [==============================] - 0s 77ms/step
# epoch:77  d_loss:0.4194  g_loss:1.1634
# 1/1 [==============================] - 0s 76ms/step
# epoch:78  d_loss:0.4907  g_loss:0.8897
# 1/1 [==============================] - 0s 81ms/step
# epoch:79  d_loss:0.9074  g_loss:0.8170
# 1/1 [==============================] - 0s 125ms/step
# epoch:80  d_loss:0.9038  g_loss:0.6734
# 1/1 [==============================] - 0s 145ms/step
# epoch:81  d_loss:1.1220  g_loss:0.5558
# 1/1 [==============================] - 0s 121ms/step
# epoch:82  d_loss:0.9305  g_loss:0.7332
# 1/1 [==============================] - 0s 76ms/step
# epoch:83  d_loss:0.9770  g_loss:0.8575
# 1/1 [==============================] - 0s 78ms/step
# epoch:84  d_loss:0.7435  g_loss:0.9922
# 1/1 [==============================] - 0s 75ms/step
# epoch:85  d_loss:0.5994  g_loss:1.1206
# 1/1 [==============================] - 0s 79ms/step
# epoch:86  d_loss:0.2958  g_loss:1.5543
# 1/1 [==============================] - 0s 76ms/step
# epoch:87  d_loss:0.1741  g_loss:1.9468
# 1/1 [==============================] - 0s 75ms/step
# epoch:88  d_loss:0.0879  g_loss:2.5333
# 1/1 [==============================] - 0s 81ms/step
# epoch:89  d_loss:0.0587  g_loss:3.1606
# 1/1 [==============================] - 0s 77ms/step
# epoch:90  d_loss:0.0691  g_loss:3.6914
# 1/1 [==============================] - 0s 75ms/step
# epoch:91  d_loss:0.0923  g_loss:3.2209
# 1/1 [==============================] - 0s 84ms/step
# epoch:92  d_loss:0.0362  g_loss:3.5536
# 1/1 [==============================] - 0s 84ms/step
# epoch:93  d_loss:0.1889  g_loss:3.1738
# 1/1 [==============================] - 0s 75ms/step
# epoch:94  d_loss:0.0975  g_loss:3.8096
# 1/1 [==============================] - 0s 77ms/step
# epoch:95  d_loss:0.2413  g_loss:3.5047
# 1/1 [==============================] - 0s 81ms/step
# epoch:96  d_loss:0.4317  g_loss:4.1958
# 1/1 [==============================] - 0s 82ms/step
# epoch:97  d_loss:0.3597  g_loss:4.5532
# 1/1 [==============================] - 0s 79ms/step
# epoch:98  d_loss:0.4428  g_loss:4.7480
# 1/1 [==============================] - 0s 140ms/step
# epoch:99  d_loss:0.7189  g_loss:4.1699
# 1/1 [==============================] - 0s 139ms/step
# epoch:100  d_loss:0.9903  g_loss:2.7766
# 1/1 [==============================] - 0s 75ms/step
# epoch:101  d_loss:0.8918  g_loss:3.0758
# 1/1 [==============================] - 0s 84ms/step
# epoch:102  d_loss:0.8451  g_loss:2.7496
# 1/1 [==============================] - 0s 74ms/step
# epoch:103  d_loss:0.9375  g_loss:2.8472
# 1/1 [==============================] - 0s 76ms/step
# epoch:104  d_loss:0.8228  g_loss:2.7090
# 1/1 [==============================] - 0s 75ms/step
# epoch:105  d_loss:0.9030  g_loss:2.5032
# 1/1 [==============================] - 0s 79ms/step
# epoch:106  d_loss:0.8731  g_loss:2.0819
# 1/1 [==============================] - 0s 80ms/step
# epoch:107  d_loss:0.7484  g_loss:1.5649
# 1/1 [==============================] - 0s 76ms/step
# epoch:108  d_loss:0.7026  g_loss:1.4636
# 1/1 [==============================] - 0s 78ms/step
# epoch:109  d_loss:0.5461  g_loss:1.6283
# 1/1 [==============================] - 0s 81ms/step
# epoch:110  d_loss:0.5300  g_loss:1.8790
# 1/1 [==============================] - 0s 78ms/step
# epoch:111  d_loss:0.5129  g_loss:1.7917
# 1/1 [==============================] - 0s 80ms/step
# epoch:112  d_loss:0.6045  g_loss:1.7177
# 1/1 [==============================] - 0s 82ms/step
# epoch:113  d_loss:0.5694  g_loss:1.3560
# 1/1 [==============================] - 0s 77ms/step
# epoch:114  d_loss:0.5770  g_loss:1.3494
# 1/1 [==============================] - 0s 78ms/step
# epoch:115  d_loss:0.5476  g_loss:1.3834
# 1/1 [==============================] - 0s 75ms/step
# epoch:116  d_loss:0.5129  g_loss:1.4995
# 1/1 [==============================] - 0s 131ms/step
# epoch:117  d_loss:0.4820  g_loss:1.6272
# 1/1 [==============================] - 0s 149ms/step
# epoch:118  d_loss:0.4734  g_loss:1.5665
# 1/1 [==============================] - 0s 130ms/step
# epoch:119  d_loss:0.4334  g_loss:1.5127
# 1/1 [==============================] - 0s 79ms/step
# epoch:120  d_loss:0.4564  g_loss:1.4604
# 1/1 [==============================] - 0s 76ms/step
# epoch:121  d_loss:0.4456  g_loss:1.4529
# 1/1 [==============================] - 0s 83ms/step
# epoch:122  d_loss:0.5235  g_loss:1.3471
# 1/1 [==============================] - 0s 80ms/step
# epoch:123  d_loss:0.5185  g_loss:1.4323
# 1/1 [==============================] - 0s 76ms/step
# epoch:124  d_loss:0.4487  g_loss:1.1843
# 1/1 [==============================] - 0s 77ms/step
# epoch:125  d_loss:0.5420  g_loss:1.1918
# 1/1 [==============================] - 0s 76ms/step
# epoch:126  d_loss:0.4771  g_loss:1.2453
# 1/1 [==============================] - 0s 75ms/step
# epoch:127  d_loss:0.4495  g_loss:1.3383
# 1/1 [==============================] - 0s 78ms/step
# epoch:128  d_loss:0.4564  g_loss:1.4659
# 1/1 [==============================] - 0s 75ms/step
# epoch:129  d_loss:0.4735  g_loss:1.3429
# 1/1 [==============================] - 0s 78ms/step
# epoch:130  d_loss:0.5868  g_loss:1.3009
# 1/1 [==============================] - 0s 81ms/step
# epoch:131  d_loss:0.5645  g_loss:1.1894
# 1/1 [==============================] - 0s 77ms/step
# epoch:132  d_loss:0.5995  g_loss:0.9840
# 1/1 [==============================] - 0s 83ms/step
# epoch:133  d_loss:0.4891  g_loss:1.0217
# 1/1 [==============================] - 0s 98ms/step
# epoch:134  d_loss:0.4966  g_loss:1.1373
# 1/1 [==============================] - 0s 79ms/step
# epoch:135  d_loss:0.6072  g_loss:1.0752
# 1/1 [==============================] - 0s 142ms/step
# epoch:136  d_loss:0.5619  g_loss:1.1628
# 1/1 [==============================] - 0s 143ms/step
# epoch:137  d_loss:0.5580  g_loss:1.0925
# 1/1 [==============================] - 0s 83ms/step
# epoch:138  d_loss:0.5736  g_loss:1.0862
# 1/1 [==============================] - 0s 86ms/step
# epoch:139  d_loss:0.4862  g_loss:1.1589
# 1/1 [==============================] - 0s 78ms/step
# epoch:140  d_loss:0.5924  g_loss:1.1046
# 1/1 [==============================] - 0s 76ms/step
# epoch:141  d_loss:0.5418  g_loss:1.0189
# 1/1 [==============================] - 0s 77ms/step
# epoch:142  d_loss:0.5736  g_loss:1.0950
# 1/1 [==============================] - 0s 76ms/step
# epoch:143  d_loss:0.6108  g_loss:0.9452
# 1/1 [==============================] - 0s 96ms/step
# epoch:144  d_loss:0.6044  g_loss:0.9669
# 1/1 [==============================] - 0s 77ms/step
# epoch:145  d_loss:0.6288  g_loss:0.9341
# 1/1 [==============================] - 0s 80ms/step
# epoch:146  d_loss:0.5627  g_loss:1.0341
# 1/1 [==============================] - 0s 80ms/step
# epoch:147  d_loss:0.6102  g_loss:1.1842
# 1/1 [==============================] - 0s 80ms/step
# epoch:148  d_loss:0.5101  g_loss:1.1766
# 1/1 [==============================] - 0s 83ms/step
# epoch:149  d_loss:0.5654  g_loss:1.2411
# 1/1 [==============================] - 0s 76ms/step
# epoch:150  d_loss:0.5105  g_loss:1.2717
# 1/1 [==============================] - 0s 76ms/step
# epoch:151  d_loss:0.4507  g_loss:1.5215
# 1/1 [==============================] - 0s 78ms/step
# epoch:152  d_loss:0.4384  g_loss:1.4999
# 1/1 [==============================] - 0s 80ms/step
# epoch:153  d_loss:0.3557  g_loss:1.4967
# 1/1 [==============================] - 0s 117ms/step
# epoch:154  d_loss:0.3977  g_loss:1.6766
# 1/1 [==============================] - 0s 137ms/step
# epoch:155  d_loss:0.3688  g_loss:2.0176
# 1/1 [==============================] - 0s 129ms/step
# epoch:156  d_loss:0.3390  g_loss:1.9145
# 1/1 [==============================] - 0s 77ms/step
# epoch:157  d_loss:0.5019  g_loss:1.7544
# 1/1 [==============================] - 0s 80ms/step
# epoch:158  d_loss:0.3959  g_loss:2.5968
# 1/1 [==============================] - 0s 83ms/step
# epoch:159  d_loss:0.2884  g_loss:2.4478
# 1/1 [==============================] - 0s 77ms/step
# epoch:160  d_loss:0.5687  g_loss:2.1951
# 1/1 [==============================] - 0s 78ms/step
# epoch:161  d_loss:0.6195  g_loss:2.1050
# 1/1 [==============================] - 0s 92ms/step
# epoch:162  d_loss:0.8742  g_loss:1.6627
# 1/1 [==============================] - 0s 77ms/step
# epoch:163  d_loss:0.7454  g_loss:1.3972
# 1/1 [==============================] - 0s 77ms/step
# epoch:164  d_loss:0.8079  g_loss:1.7126
# 1/1 [==============================] - 0s 81ms/step
# epoch:165  d_loss:0.6745  g_loss:2.1129
# 1/1 [==============================] - 0s 78ms/step
# epoch:166  d_loss:0.8819  g_loss:1.7014
# 1/1 [==============================] - 0s 92ms/step
# epoch:167  d_loss:0.9453  g_loss:1.4356
# 1/1 [==============================] - 0s 78ms/step
# epoch:168  d_loss:0.7550  g_loss:1.6458
# 1/1 [==============================] - 0s 78ms/step
# epoch:169  d_loss:0.7921  g_loss:1.1820
# 1/1 [==============================] - 0s 76ms/step
# epoch:170  d_loss:0.8523  g_loss:1.1613
# 1/1 [==============================] - 0s 77ms/step
# epoch:171  d_loss:0.7518  g_loss:1.5197
# 1/1 [==============================] - 0s 89ms/step
# epoch:172  d_loss:0.6056  g_loss:1.5509
# 1/1 [==============================] - 0s 125ms/step
# epoch:173  d_loss:0.5293  g_loss:1.5017
# 1/1 [==============================] - 0s 138ms/step
# epoch:174  d_loss:0.5480  g_loss:1.6390
# 1/1 [==============================] - 0s 130ms/step
# epoch:175  d_loss:0.5347  g_loss:1.8861
# 1/1 [==============================] - 0s 75ms/step
# epoch:176  d_loss:0.4557  g_loss:1.9321
# 1/1 [==============================] - 0s 83ms/step
# epoch:177  d_loss:0.4512  g_loss:1.6376
# 1/1 [==============================] - 0s 77ms/step
# epoch:178  d_loss:0.4439  g_loss:1.7172
# 1/1 [==============================] - 0s 82ms/step
# epoch:179  d_loss:0.5057  g_loss:1.5594
# 1/1 [==============================] - 0s 79ms/step
# epoch:180  d_loss:0.4927  g_loss:1.6928
# 1/1 [==============================] - 0s 75ms/step
# epoch:181  d_loss:0.4199  g_loss:1.4519
# 1/1 [==============================] - 0s 94ms/step
# epoch:182  d_loss:0.4222  g_loss:1.6989
# 1/1 [==============================] - 0s 79ms/step
# epoch:183  d_loss:0.3436  g_loss:1.4900
# 1/1 [==============================] - 0s 78ms/step
# epoch:184  d_loss:0.3924  g_loss:1.5149
# 1/1 [==============================] - 0s 76ms/step
# epoch:185  d_loss:0.3535  g_loss:1.8358
# 1/1 [==============================] - 0s 79ms/step
# epoch:186  d_loss:0.3431  g_loss:1.9721
# 1/1 [==============================] - 0s 105ms/step
# epoch:187  d_loss:0.3545  g_loss:1.9754
# 1/1 [==============================] - 0s 81ms/step
# epoch:188  d_loss:0.2304  g_loss:2.1398
# 1/1 [==============================] - 0s 77ms/step
# epoch:189  d_loss:0.3284  g_loss:2.0184
# 1/1 [==============================] - 0s 76ms/step
# epoch:190  d_loss:0.3780  g_loss:1.8344
# 1/1 [==============================] - 0s 89ms/step
# epoch:191  d_loss:0.3125  g_loss:1.7795
# 1/1 [==============================] - 0s 134ms/step
# epoch:192  d_loss:0.3751  g_loss:1.7636
# 1/1 [==============================] - 0s 129ms/step
# epoch:193  d_loss:0.3025  g_loss:1.9781
# 1/1 [==============================] - 0s 81ms/step
# epoch:194  d_loss:0.3610  g_loss:2.0143
# 1/1 [==============================] - 0s 78ms/step
# epoch:195  d_loss:0.2553  g_loss:2.0834
# 1/1 [==============================] - 0s 88ms/step
# epoch:196  d_loss:0.3912  g_loss:1.8446
# 1/1 [==============================] - 0s 90ms/step
# epoch:197  d_loss:0.4679  g_loss:1.5977
# 1/1 [==============================] - 0s 83ms/step
# epoch:198  d_loss:0.3521  g_loss:1.6869
# 1/1 [==============================] - 0s 75ms/step
# epoch:199  d_loss:0.4743  g_loss:1.6142
# 1/1 [==============================] - 0s 75ms/step
# epoch:200  d_loss:0.3647  g_loss:1.6897
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 78ms/step
# epoch:201  d_loss:0.4350  g_loss:1.6416
# 1/1 [==============================] - 0s 94ms/step
# epoch:202  d_loss:0.5098  g_loss:1.8632
# 1/1 [==============================] - 0s 76ms/step
# epoch:203  d_loss:0.3100  g_loss:2.0302
# 1/1 [==============================] - 0s 76ms/step
# epoch:204  d_loss:0.4634  g_loss:2.0777
# 1/1 [==============================] - 0s 77ms/step
# epoch:205  d_loss:0.6836  g_loss:1.5018
# 1/1 [==============================] - 0s 81ms/step
# epoch:206  d_loss:0.6277  g_loss:1.3793
# 1/1 [==============================] - 0s 98ms/step
# epoch:207  d_loss:0.5069  g_loss:1.5634
# 1/1 [==============================] - 0s 76ms/step
# epoch:208  d_loss:0.4105  g_loss:1.6098
# 1/1 [==============================] - 0s 129ms/step
# epoch:209  d_loss:0.5560  g_loss:1.7483
# 1/1 [==============================] - 0s 139ms/step
# epoch:210  d_loss:0.6602  g_loss:1.8139
# 1/1 [==============================] - 0s 80ms/step
# epoch:211  d_loss:0.5500  g_loss:1.5091
# 1/1 [==============================] - 0s 77ms/step
# epoch:212  d_loss:0.5173  g_loss:1.6922
# 1/1 [==============================] - 0s 78ms/step
# epoch:213  d_loss:0.5579  g_loss:1.7604
# 1/1 [==============================] - 0s 78ms/step
# epoch:214  d_loss:0.4610  g_loss:1.7427
# 1/1 [==============================] - 0s 75ms/step
# epoch:215  d_loss:0.5058  g_loss:1.8468
# 1/1 [==============================] - 0s 83ms/step
# epoch:216  d_loss:0.5003  g_loss:1.8187
# 1/1 [==============================] - 0s 83ms/step
# epoch:217  d_loss:0.5320  g_loss:1.6241
# 1/1 [==============================] - 0s 76ms/step
# epoch:218  d_loss:0.5438  g_loss:1.7628
# 1/1 [==============================] - 0s 75ms/step
# epoch:219  d_loss:0.5185  g_loss:1.9665
# 1/1 [==============================] - 0s 78ms/step
# epoch:220  d_loss:0.4806  g_loss:1.7886
# 1/1 [==============================] - 0s 81ms/step
# epoch:221  d_loss:0.5730  g_loss:2.1036
# 1/1 [==============================] - 0s 91ms/step
# epoch:222  d_loss:0.3952  g_loss:2.3245
# 1/1 [==============================] - 0s 76ms/step
# epoch:223  d_loss:0.6424  g_loss:2.1496
# 1/1 [==============================] - 0s 75ms/step
# epoch:224  d_loss:0.4217  g_loss:2.2583
# 1/1 [==============================] - 0s 76ms/step
# epoch:225  d_loss:0.4707  g_loss:1.9016
# 1/1 [==============================] - 0s 85ms/step
# epoch:226  d_loss:0.3726  g_loss:1.9815
# 1/1 [==============================] - 0s 142ms/step
# epoch:227  d_loss:0.3066  g_loss:2.2000
# 1/1 [==============================] - 0s 154ms/step
# epoch:228  d_loss:0.3473  g_loss:2.6450
# 1/1 [==============================] - 0s 126ms/step
# epoch:229  d_loss:0.5373  g_loss:2.5310
# 1/1 [==============================] - 0s 76ms/step
# epoch:230  d_loss:0.3537  g_loss:2.6263
# 1/1 [==============================] - 0s 80ms/step
# epoch:231  d_loss:0.3851  g_loss:2.6446
# 1/1 [==============================] - 0s 77ms/step
# epoch:232  d_loss:0.3923  g_loss:2.2816
# 1/1 [==============================] - 0s 75ms/step
# epoch:233  d_loss:0.4002  g_loss:2.1923
# 1/1 [==============================] - 0s 76ms/step
# epoch:234  d_loss:0.4289  g_loss:2.0924
# 1/1 [==============================] - 0s 77ms/step
# epoch:235  d_loss:0.5089  g_loss:1.7379
# 1/1 [==============================] - 0s 80ms/step
# epoch:236  d_loss:0.3946  g_loss:1.9323
# 1/1 [==============================] - 0s 80ms/step
# epoch:237  d_loss:0.4476  g_loss:2.3228
# 1/1 [==============================] - 0s 79ms/step
# epoch:238  d_loss:0.3173  g_loss:1.9081
# 1/1 [==============================] - 0s 75ms/step
# epoch:239  d_loss:0.3474  g_loss:2.0913
# 1/1 [==============================] - 0s 79ms/step
# epoch:240  d_loss:0.3692  g_loss:2.0511
# 1/1 [==============================] - 0s 79ms/step
# epoch:241  d_loss:0.5113  g_loss:1.7574
# 1/1 [==============================] - 0s 139ms/step
# epoch:242  d_loss:0.4541  g_loss:1.9869
# 1/1 [==============================] - 0s 123ms/step
# epoch:243  d_loss:0.3683  g_loss:2.0128
# 1/1 [==============================] - 0s 132ms/step
# epoch:244  d_loss:0.3843  g_loss:1.9450
# 1/1 [==============================] - 0s 116ms/step
# epoch:245  d_loss:0.3649  g_loss:1.8292
# 1/1 [==============================] - 0s 131ms/step
# epoch:246  d_loss:0.3533  g_loss:2.0464
# 1/1 [==============================] - 0s 77ms/step
# epoch:247  d_loss:0.4938  g_loss:1.9382
# 1/1 [==============================] - 0s 77ms/step
# epoch:248  d_loss:0.4004  g_loss:1.7714
# 1/1 [==============================] - 0s 75ms/step
# epoch:249  d_loss:0.4673  g_loss:1.6432
# 1/1 [==============================] - 0s 75ms/step
# epoch:250  d_loss:0.3636  g_loss:1.7453
# 1/1 [==============================] - 0s 79ms/step
# epoch:251  d_loss:0.4561  g_loss:1.4389
# 1/1 [==============================] - 0s 79ms/step
# epoch:252  d_loss:0.4501  g_loss:1.2631
# 1/1 [==============================] - 0s 78ms/step
# epoch:253  d_loss:0.5418  g_loss:1.9877
# 1/1 [==============================] - 0s 80ms/step
# epoch:254  d_loss:0.5117  g_loss:2.0055
# 1/1 [==============================] - 0s 80ms/step
# epoch:255  d_loss:0.4610  g_loss:2.0131
# 1/1 [==============================] - 0s 80ms/step
# epoch:256  d_loss:0.5346  g_loss:1.6807
# 1/1 [==============================] - 0s 75ms/step
# epoch:257  d_loss:0.6467  g_loss:1.7611
# 1/1 [==============================] - 0s 75ms/step
# epoch:258  d_loss:0.6270  g_loss:1.4467
# 1/1 [==============================] - 0s 79ms/step
# epoch:259  d_loss:0.6581  g_loss:1.4337
# 1/1 [==============================] - 0s 81ms/step
# epoch:260  d_loss:0.6321  g_loss:1.2750
# 1/1 [==============================] - 0s 80ms/step
# epoch:261  d_loss:0.4938  g_loss:1.3645
# 1/1 [==============================] - 0s 94ms/step
# epoch:262  d_loss:0.5752  g_loss:1.4027
# 1/1 [==============================] - 0s 115ms/step
# epoch:263  d_loss:0.5477  g_loss:1.5729
# 1/1 [==============================] - 0s 142ms/step
# epoch:264  d_loss:0.7141  g_loss:1.4461
# 1/1 [==============================] - 0s 128ms/step
# epoch:265  d_loss:0.5431  g_loss:1.5012
# 1/1 [==============================] - 0s 76ms/step
# epoch:266  d_loss:0.5419  g_loss:1.5493
# 1/1 [==============================] - 0s 90ms/step
# epoch:267  d_loss:0.6007  g_loss:1.2057
# 1/1 [==============================] - 0s 75ms/step
# epoch:268  d_loss:0.4838  g_loss:1.4504
# 1/1 [==============================] - 0s 80ms/step
# epoch:269  d_loss:0.5650  g_loss:1.5915
# 1/1 [==============================] - 0s 78ms/step
# epoch:270  d_loss:0.5962  g_loss:1.3526
# 1/1 [==============================] - 0s 76ms/step
# epoch:271  d_loss:0.4478  g_loss:1.7337
# 1/1 [==============================] - 0s 92ms/step
# epoch:272  d_loss:0.4589  g_loss:1.5289
# 1/1 [==============================] - 0s 75ms/step
# epoch:273  d_loss:0.4898  g_loss:1.4872
# 1/1 [==============================] - 0s 77ms/step
# epoch:274  d_loss:0.4740  g_loss:1.4873
# 1/1 [==============================] - 0s 81ms/step
# epoch:275  d_loss:0.4740  g_loss:1.8518
# 1/1 [==============================] - 0s 77ms/step
# epoch:276  d_loss:0.5209  g_loss:1.8584
# 1/1 [==============================] - 0s 95ms/step
# epoch:277  d_loss:0.3955  g_loss:1.9951
# 1/1 [==============================] - 0s 84ms/step
# epoch:278  d_loss:0.3591  g_loss:1.8763
# 1/1 [==============================] - 0s 83ms/step
# epoch:279  d_loss:0.5134  g_loss:1.8563
# 1/1 [==============================] - 0s 78ms/step
# epoch:280  d_loss:0.4895  g_loss:1.5775
# 1/1 [==============================] - 0s 76ms/step
# epoch:281  d_loss:0.4307  g_loss:1.8143
# 1/1 [==============================] - 0s 124ms/step
# epoch:282  d_loss:0.3381  g_loss:2.0889
# 1/1 [==============================] - 0s 142ms/step
# epoch:283  d_loss:0.3845  g_loss:2.0371
# 1/1 [==============================] - 0s 134ms/step
# epoch:284  d_loss:0.4905  g_loss:2.1044
# 1/1 [==============================] - 0s 76ms/step
# epoch:285  d_loss:0.4747  g_loss:1.8593
# 1/1 [==============================] - 0s 83ms/step
# epoch:286  d_loss:0.3791  g_loss:1.9986
# 1/1 [==============================] - 0s 94ms/step
# epoch:287  d_loss:0.3955  g_loss:1.9394
# 1/1 [==============================] - 0s 76ms/step
# epoch:288  d_loss:0.3565  g_loss:2.4350
# 1/1 [==============================] - 0s 75ms/step
# epoch:289  d_loss:0.3615  g_loss:2.2080
# 1/1 [==============================] - 0s 77ms/step
# epoch:290  d_loss:0.5171  g_loss:2.1057
# 1/1 [==============================] - 0s 74ms/step
# epoch:291  d_loss:0.5198  g_loss:1.9840
# 1/1 [==============================] - 0s 89ms/step
# epoch:292  d_loss:0.5637  g_loss:2.0496
# 1/1 [==============================] - 0s 79ms/step
# epoch:293  d_loss:0.4438  g_loss:1.6349
# 1/1 [==============================] - 0s 82ms/step
# epoch:294  d_loss:0.5917  g_loss:1.7906
# 1/1 [==============================] - 0s 78ms/step
# epoch:295  d_loss:0.4354  g_loss:2.1430
# 1/1 [==============================] - 0s 86ms/step
# epoch:296  d_loss:0.4606  g_loss:2.0058
# 1/1 [==============================] - 0s 77ms/step
# epoch:297  d_loss:0.4377  g_loss:2.4767
# 1/1 [==============================] - 0s 78ms/step
# epoch:298  d_loss:0.4998  g_loss:1.9113
# 1/1 [==============================] - 0s 78ms/step
# epoch:299  d_loss:0.5354  g_loss:2.0609
# 1/1 [==============================] - 0s 81ms/step
# epoch:300  d_loss:0.4288  g_loss:1.8243
# 1/1 [==============================] - 0s 118ms/step
# epoch:301  d_loss:0.4307  g_loss:1.9192
# 1/1 [==============================] - 0s 128ms/step
# epoch:302  d_loss:0.4425  g_loss:2.3164
# 1/1 [==============================] - 0s 75ms/step
# epoch:303  d_loss:0.3671  g_loss:2.7023
# 1/1 [==============================] - 0s 77ms/step
# epoch:304  d_loss:0.4074  g_loss:2.6148
# 1/1 [==============================] - 0s 77ms/step
# epoch:305  d_loss:0.4896  g_loss:2.3609
# 1/1 [==============================] - 0s 77ms/step
# epoch:306  d_loss:0.4870  g_loss:2.1812
# 1/1 [==============================] - 0s 79ms/step
# epoch:307  d_loss:0.4078  g_loss:2.1366
# 1/1 [==============================] - 0s 79ms/step
# epoch:308  d_loss:0.4761  g_loss:2.3097
# 1/1 [==============================] - 0s 77ms/step
# epoch:309  d_loss:0.3858  g_loss:2.2907
# 1/1 [==============================] - 0s 93ms/step
# epoch:310  d_loss:0.5171  g_loss:2.6237
# 1/1 [==============================] - 0s 74ms/step
# epoch:311  d_loss:0.4123  g_loss:2.6542
# 1/1 [==============================] - 0s 75ms/step
# epoch:312  d_loss:0.5824  g_loss:2.2878
# 1/1 [==============================] - 0s 78ms/step
# epoch:313  d_loss:0.5322  g_loss:1.8642
# 1/1 [==============================] - 0s 77ms/step
# epoch:314  d_loss:0.4681  g_loss:1.6974
# 1/1 [==============================] - 0s 77ms/step
# epoch:315  d_loss:0.5581  g_loss:1.6098
# 1/1 [==============================] - 0s 79ms/step
# epoch:316  d_loss:0.3381  g_loss:2.5162
# 1/1 [==============================] - 0s 79ms/step
# epoch:317  d_loss:0.4164  g_loss:2.4277
# 1/1 [==============================] - 0s 79ms/step
# epoch:318  d_loss:0.3890  g_loss:2.4372
# 1/1 [==============================] - 0s 139ms/step
# epoch:319  d_loss:0.5333  g_loss:1.9248
# 1/1 [==============================] - 0s 141ms/step
# epoch:320  d_loss:0.4220  g_loss:1.6326
# 1/1 [==============================] - 0s 129ms/step
# epoch:321  d_loss:0.4824  g_loss:1.5139
# 1/1 [==============================] - 0s 75ms/step
# epoch:322  d_loss:0.5076  g_loss:1.7157
# 1/1 [==============================] - 0s 78ms/step
# epoch:323  d_loss:0.3518  g_loss:2.1321
# 1/1 [==============================] - 0s 76ms/step
# epoch:324  d_loss:0.4124  g_loss:2.0518
# 1/1 [==============================] - 0s 89ms/step
# epoch:325  d_loss:0.3726  g_loss:2.1534
# 1/1 [==============================] - 0s 78ms/step
# epoch:326  d_loss:0.3414  g_loss:2.2651
# 1/1 [==============================] - 0s 77ms/step
# epoch:327  d_loss:0.3841  g_loss:2.0308
# 1/1 [==============================] - 0s 83ms/step
# epoch:328  d_loss:0.3413  g_loss:1.9924
# 1/1 [==============================] - 0s 83ms/step
# epoch:329  d_loss:0.2041  g_loss:2.5382
# 1/1 [==============================] - 0s 91ms/step
# epoch:330  d_loss:0.3336  g_loss:2.0219
# 1/1 [==============================] - 0s 87ms/step
# epoch:331  d_loss:0.2758  g_loss:2.3069
# 1/1 [==============================] - 0s 76ms/step
# epoch:332  d_loss:0.2520  g_loss:2.3000
# 1/1 [==============================] - 0s 78ms/step
# epoch:333  d_loss:0.2367  g_loss:2.6463
# 1/1 [==============================] - 0s 78ms/step
# epoch:334  d_loss:0.1987  g_loss:2.5218
# 1/1 [==============================] - 0s 79ms/step
# epoch:335  d_loss:0.3239  g_loss:2.2637
# 1/1 [==============================] - 0s 81ms/step
# epoch:336  d_loss:0.2317  g_loss:2.5379
# 1/1 [==============================] - 0s 78ms/step
# epoch:337  d_loss:0.3657  g_loss:2.3965
# 1/1 [==============================] - 0s 147ms/step
# epoch:338  d_loss:0.3702  g_loss:1.7965
# 1/1 [==============================] - 0s 130ms/step
# epoch:339  d_loss:0.3788  g_loss:2.1904
# 1/1 [==============================] - 0s 83ms/step
# epoch:340  d_loss:0.3692  g_loss:2.0490
# 1/1 [==============================] - 0s 75ms/step
# epoch:341  d_loss:0.3304  g_loss:2.2950
# 1/1 [==============================] - 0s 75ms/step
# epoch:342  d_loss:0.3885  g_loss:2.4973
# 1/1 [==============================] - 0s 76ms/step
# epoch:343  d_loss:0.3793  g_loss:2.4358
# 1/1 [==============================] - 0s 76ms/step
# epoch:344  d_loss:0.3720  g_loss:1.9530
# 1/1 [==============================] - 0s 75ms/step
# epoch:345  d_loss:0.3713  g_loss:1.4520
# 1/1 [==============================] - 0s 77ms/step
# epoch:346  d_loss:0.3819  g_loss:1.2375
# 1/1 [==============================] - 0s 86ms/step
# epoch:347  d_loss:0.3176  g_loss:1.6132
# 1/1 [==============================] - 0s 77ms/step
# epoch:348  d_loss:0.2689  g_loss:2.1288
# 1/1 [==============================] - 0s 76ms/step
# epoch:349  d_loss:0.3898  g_loss:2.5379
# 1/1 [==============================] - 0s 77ms/step
# epoch:350  d_loss:0.2932  g_loss:2.7378
# 1/1 [==============================] - 0s 76ms/step
# epoch:351  d_loss:0.4128  g_loss:2.5725
# 1/1 [==============================] - 0s 80ms/step
# epoch:352  d_loss:0.4046  g_loss:1.9211
# 1/1 [==============================] - 0s 81ms/step
# epoch:353  d_loss:0.4228  g_loss:1.5359
# 1/1 [==============================] - 0s 76ms/step
# epoch:354  d_loss:0.3741  g_loss:1.7483
# 1/1 [==============================] - 0s 77ms/step
# epoch:355  d_loss:0.3729  g_loss:1.6473
# 1/1 [==============================] - 0s 131ms/step
# epoch:356  d_loss:0.2920  g_loss:2.0523
# 1/1 [==============================] - 0s 145ms/step
# epoch:357  d_loss:0.2588  g_loss:2.2832
# 1/1 [==============================] - 0s 131ms/step
# epoch:358  d_loss:0.2874  g_loss:2.6655
# 1/1 [==============================] - 0s 75ms/step
# epoch:359  d_loss:0.4425  g_loss:2.3882
# 1/1 [==============================] - 0s 82ms/step
# epoch:360  d_loss:0.3541  g_loss:1.9484
# 1/1 [==============================] - 0s 80ms/step
# epoch:361  d_loss:0.3016  g_loss:1.6953
# 1/1 [==============================] - 0s 80ms/step
# epoch:362  d_loss:0.3859  g_loss:1.6511
# 1/1 [==============================] - 0s 89ms/step
# epoch:363  d_loss:0.3243  g_loss:1.7790
# 1/1 [==============================] - 0s 77ms/step
# epoch:364  d_loss:0.3140  g_loss:2.3002
# 1/1 [==============================] - 0s 78ms/step
# epoch:365  d_loss:0.4304  g_loss:2.9371
# 1/1 [==============================] - 0s 77ms/step
# epoch:366  d_loss:0.4166  g_loss:2.5201
# 1/1 [==============================] - 0s 76ms/step
# epoch:367  d_loss:0.3174  g_loss:2.1292
# 1/1 [==============================] - 0s 91ms/step
# epoch:368  d_loss:0.3881  g_loss:2.1436
# 1/1 [==============================] - 0s 91ms/step
# epoch:369  d_loss:0.3417  g_loss:2.3109
# 1/1 [==============================] - 0s 75ms/step
# epoch:370  d_loss:0.4741  g_loss:2.4883
# 1/1 [==============================] - 0s 75ms/step
# epoch:371  d_loss:0.4300  g_loss:2.3601
# 1/1 [==============================] - 0s 79ms/step
# epoch:372  d_loss:0.5198  g_loss:2.8279
# 1/1 [==============================] - 0s 79ms/step
# epoch:373  d_loss:0.3212  g_loss:3.5219
# 1/1 [==============================] - 0s 77ms/step
# epoch:374  d_loss:0.4277  g_loss:3.1352
# 1/1 [==============================] - 0s 120ms/step
# epoch:375  d_loss:0.5722  g_loss:2.2814
# 1/1 [==============================] - 0s 132ms/step
# epoch:376  d_loss:0.4316  g_loss:2.6401
# 1/1 [==============================] - 0s 132ms/step
# epoch:377  d_loss:0.3327  g_loss:2.1679
# 1/1 [==============================] - 0s 92ms/step
# epoch:378  d_loss:0.3673  g_loss:2.8303
# 1/1 [==============================] - 0s 80ms/step
# epoch:379  d_loss:0.3174  g_loss:3.1282
# 1/1 [==============================] - 0s 80ms/step
# epoch:380  d_loss:0.3813  g_loss:2.1507
# 1/1 [==============================] - 0s 81ms/step
# epoch:381  d_loss:0.3818  g_loss:2.2392
# 1/1 [==============================] - 0s 75ms/step
# epoch:382  d_loss:0.2826  g_loss:2.3907
# 1/1 [==============================] - 0s 95ms/step
# epoch:383  d_loss:0.4386  g_loss:2.1779
# 1/1 [==============================] - 0s 77ms/step
# epoch:384  d_loss:0.3303  g_loss:2.6883
# 1/1 [==============================] - 0s 82ms/step
# epoch:385  d_loss:0.2733  g_loss:2.8377
# 1/1 [==============================] - 0s 78ms/step
# epoch:386  d_loss:0.3457  g_loss:2.8703
# 1/1 [==============================] - 0s 79ms/step
# epoch:387  d_loss:0.3270  g_loss:2.3873
# 1/1 [==============================] - 0s 76ms/step
# epoch:388  d_loss:0.3379  g_loss:2.5152
# 1/1 [==============================] - 0s 75ms/step
# epoch:389  d_loss:0.2702  g_loss:2.7910
# 1/1 [==============================] - 0s 78ms/step
# epoch:390  d_loss:0.3116  g_loss:2.2664
# 1/1 [==============================] - 0s 81ms/step
# epoch:391  d_loss:0.3434  g_loss:2.2065
# 1/1 [==============================] - 0s 80ms/step
# epoch:392  d_loss:0.2494  g_loss:2.0435
# 1/1 [==============================] - 0s 84ms/step
# epoch:393  d_loss:0.1927  g_loss:2.5028
# 1/1 [==============================] - 0s 146ms/step
# epoch:394  d_loss:0.1825  g_loss:2.5789
# 1/1 [==============================] - 0s 137ms/step
# epoch:395  d_loss:0.2147  g_loss:2.5989
# 1/1 [==============================] - 0s 120ms/step
# epoch:396  d_loss:0.2120  g_loss:2.5921
# 1/1 [==============================] - 0s 75ms/step
# epoch:397  d_loss:0.1721  g_loss:2.7581
# 1/1 [==============================] - 0s 76ms/step
# epoch:398  d_loss:0.1605  g_loss:2.4538
# 1/1 [==============================] - 0s 76ms/step
# epoch:399  d_loss:0.1774  g_loss:2.9698
# 1/1 [==============================] - 0s 81ms/step
# epoch:400  d_loss:0.1951  g_loss:2.7007
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 76ms/step
# epoch:401  d_loss:0.1986  g_loss:2.9590
# 1/1 [==============================] - 0s 77ms/step
# epoch:402  d_loss:0.2279  g_loss:2.8214
# 1/1 [==============================] - 0s 81ms/step
# epoch:403  d_loss:0.1345  g_loss:2.7819
# 1/1 [==============================] - 0s 80ms/step
# epoch:404  d_loss:0.1455  g_loss:3.0619
# 1/1 [==============================] - 0s 85ms/step
# epoch:405  d_loss:0.2109  g_loss:2.8583
# 1/1 [==============================] - 0s 75ms/step
# epoch:406  d_loss:0.1481  g_loss:2.6252
# 1/1 [==============================] - 0s 77ms/step
# epoch:407  d_loss:0.1806  g_loss:3.0866
# 1/1 [==============================] - 0s 77ms/step
# epoch:408  d_loss:0.1850  g_loss:2.5795
# 1/1 [==============================] - 0s 75ms/step
# epoch:409  d_loss:0.1554  g_loss:3.1804
# 1/1 [==============================] - 0s 85ms/step
# epoch:410  d_loss:0.2097  g_loss:3.3056
# 1/1 [==============================] - 0s 122ms/step
# epoch:411  d_loss:0.1364  g_loss:3.0509
# 1/1 [==============================] - 0s 145ms/step
# epoch:412  d_loss:0.1765  g_loss:3.1041
# 1/1 [==============================] - 0s 121ms/step
# epoch:413  d_loss:0.2424  g_loss:2.8269
# 1/1 [==============================] - 0s 84ms/step
# epoch:414  d_loss:0.2980  g_loss:2.3482
# 1/1 [==============================] - 0s 80ms/step
# epoch:415  d_loss:0.1560  g_loss:2.8429
# 1/1 [==============================] - 0s 79ms/step
# epoch:416  d_loss:0.3248  g_loss:2.6075
# 1/1 [==============================] - 0s 76ms/step
# epoch:417  d_loss:0.2005  g_loss:3.0675
# 1/1 [==============================] - 0s 82ms/step
# epoch:418  d_loss:0.3028  g_loss:2.3868
# 1/1 [==============================] - 0s 79ms/step
# epoch:419  d_loss:0.3230  g_loss:3.1268
# 1/1 [==============================] - 0s 126ms/step
# epoch:420  d_loss:0.3369  g_loss:2.8280
# 1/1 [==============================] - 0s 141ms/step
# epoch:421  d_loss:0.4375  g_loss:1.9723
# 1/1 [==============================] - 0s 142ms/step
# epoch:422  d_loss:0.2564  g_loss:1.9946
# 1/1 [==============================] - 0s 75ms/step
# epoch:423  d_loss:0.3185  g_loss:2.4076
# 1/1 [==============================] - 0s 77ms/step
# epoch:424  d_loss:0.2343  g_loss:2.6200
# 1/1 [==============================] - 0s 79ms/step
# epoch:425  d_loss:0.2812  g_loss:2.4995
# 1/1 [==============================] - 0s 83ms/step
# epoch:426  d_loss:0.2619  g_loss:2.1940
# 1/1 [==============================] - 0s 75ms/step
# epoch:427  d_loss:0.2117  g_loss:2.0577
# 1/1 [==============================] - 0s 76ms/step
# epoch:428  d_loss:0.3574  g_loss:1.8365
# 1/1 [==============================] - 0s 138ms/step
# epoch:429  d_loss:0.2349  g_loss:2.0987
# 1/1 [==============================] - 0s 137ms/step
# epoch:430  d_loss:0.3904  g_loss:2.4277
# 1/1 [==============================] - 0s 113ms/step
# epoch:431  d_loss:0.2496  g_loss:2.5437
# 1/1 [==============================] - 0s 94ms/step
# epoch:432  d_loss:0.3422  g_loss:2.7996
# 1/1 [==============================] - 0s 78ms/step
# epoch:433  d_loss:0.3077  g_loss:2.3732
# 1/1 [==============================] - 0s 85ms/step
# epoch:434  d_loss:0.3219  g_loss:1.8634
# 1/1 [==============================] - 0s 75ms/step
# epoch:435  d_loss:0.2050  g_loss:2.3923
# 1/1 [==============================] - 0s 80ms/step
# epoch:436  d_loss:0.2470  g_loss:3.0373
# 1/1 [==============================] - 0s 89ms/step
# epoch:437  d_loss:0.2481  g_loss:3.2652
# 1/1 [==============================] - 0s 79ms/step
# epoch:438  d_loss:0.3181  g_loss:2.7193
# 1/1 [==============================] - 0s 80ms/step
# epoch:439  d_loss:0.1730  g_loss:3.0082
# 1/1 [==============================] - 0s 75ms/step
# epoch:440  d_loss:0.1159  g_loss:2.7082
# 1/1 [==============================] - 0s 76ms/step
# epoch:441  d_loss:0.2092  g_loss:3.0405
# 1/1 [==============================] - 0s 77ms/step
# epoch:442  d_loss:0.2234  g_loss:2.7270
# 1/1 [==============================] - 0s 76ms/step
# epoch:443  d_loss:0.2041  g_loss:2.7061
# 1/1 [==============================] - 0s 78ms/step
# epoch:444  d_loss:0.1653  g_loss:2.7196
# 1/1 [==============================] - 0s 97ms/step
# epoch:445  d_loss:0.1164  g_loss:3.0386
# 1/1 [==============================] - 0s 79ms/step
# epoch:446  d_loss:0.1665  g_loss:3.5002
# 1/1 [==============================] - 0s 127ms/step
# epoch:447  d_loss:0.0824  g_loss:3.5980
# 1/1 [==============================] - 0s 145ms/step
# epoch:448  d_loss:0.2431  g_loss:2.1219
# 1/1 [==============================] - 0s 136ms/step
# epoch:449  d_loss:0.2070  g_loss:2.0151
# 1/1 [==============================] - 0s 80ms/step
# epoch:450  d_loss:0.1995  g_loss:2.8192
# 1/1 [==============================] - 0s 82ms/step
# epoch:451  d_loss:0.1350  g_loss:3.5815
# 1/1 [==============================] - 0s 80ms/step
# epoch:452  d_loss:0.1755  g_loss:3.2979
# 1/1 [==============================] - 0s 77ms/step
# epoch:453  d_loss:0.2402  g_loss:3.1918
# 1/1 [==============================] - 0s 76ms/step
# epoch:454  d_loss:0.1539  g_loss:2.8494
# 1/1 [==============================] - 0s 75ms/step
# epoch:455  d_loss:0.2207  g_loss:2.6516
# 1/1 [==============================] - 0s 80ms/step
# epoch:456  d_loss:0.2209  g_loss:2.7021
# 1/1 [==============================] - 0s 76ms/step
# epoch:457  d_loss:0.2251  g_loss:3.3960
# 1/1 [==============================] - 0s 76ms/step
# epoch:458  d_loss:0.1733  g_loss:3.4972
# 1/1 [==============================] - 0s 78ms/step
# epoch:459  d_loss:0.1945  g_loss:2.8812
# 1/1 [==============================] - 0s 78ms/step
# epoch:460  d_loss:0.1532  g_loss:2.6151
# 1/1 [==============================] - 0s 78ms/step
# epoch:461  d_loss:0.2730  g_loss:2.3109
# 1/1 [==============================] - 0s 78ms/step
# epoch:462  d_loss:0.1488  g_loss:2.9043
# 1/1 [==============================] - 0s 79ms/step
# epoch:463  d_loss:0.0956  g_loss:3.0014
# 1/1 [==============================] - 0s 76ms/step
# epoch:464  d_loss:0.1338  g_loss:3.6359
# 1/1 [==============================] - 0s 75ms/step
# epoch:465  d_loss:0.1421  g_loss:3.2783
# 1/1 [==============================] - 0s 130ms/step
# epoch:466  d_loss:0.2322  g_loss:3.1010
# 1/1 [==============================] - 0s 141ms/step
# epoch:467  d_loss:0.3578  g_loss:2.4777
# 1/1 [==============================] - 0s 142ms/step
# epoch:468  d_loss:0.2652  g_loss:2.6845
# 1/1 [==============================] - 0s 82ms/step
# epoch:469  d_loss:0.2524  g_loss:3.4882
# 1/1 [==============================] - 0s 75ms/step
# epoch:470  d_loss:0.1925  g_loss:3.2076
# 1/1 [==============================] - 0s 79ms/step
# epoch:471  d_loss:0.1985  g_loss:2.8538
# 1/1 [==============================] - 0s 76ms/step
# epoch:472  d_loss:0.2497  g_loss:2.3821
# 1/1 [==============================] - 0s 76ms/step
# epoch:473  d_loss:0.3743  g_loss:3.0378
# 1/1 [==============================] - 0s 79ms/step
# epoch:474  d_loss:0.1804  g_loss:3.7679
# 1/1 [==============================] - 0s 83ms/step
# epoch:475  d_loss:0.2688  g_loss:3.3345
# 1/1 [==============================] - 0s 80ms/step
# epoch:476  d_loss:0.3150  g_loss:2.7510
# 1/1 [==============================] - 0s 81ms/step
# epoch:477  d_loss:0.4470  g_loss:2.1444
# 1/1 [==============================] - 0s 80ms/step
# epoch:478  d_loss:0.2921  g_loss:3.0162
# 1/1 [==============================] - 0s 82ms/step
# epoch:479  d_loss:0.2574  g_loss:2.6763
# 1/1 [==============================] - 0s 91ms/step
# epoch:480  d_loss:0.3555  g_loss:2.6914
# 1/1 [==============================] - 0s 76ms/step
# epoch:481  d_loss:0.2294  g_loss:2.8660
# 1/1 [==============================] - 0s 77ms/step
# epoch:482  d_loss:0.1643  g_loss:3.1357
# 1/1 [==============================] - 0s 76ms/step
# epoch:483  d_loss:0.2265  g_loss:3.1939
# 1/1 [==============================] - 0s 74ms/step
# epoch:484  d_loss:0.1817  g_loss:2.8167
# 1/1 [==============================] - 0s 127ms/step
# epoch:485  d_loss:0.3459  g_loss:2.6048
# 1/1 [==============================] - 0s 138ms/step
# epoch:486  d_loss:0.2147  g_loss:2.7694
# 1/1 [==============================] - 0s 118ms/step
# epoch:487  d_loss:0.1698  g_loss:2.7197
# 1/1 [==============================] - 0s 78ms/step
# epoch:488  d_loss:0.1087  g_loss:3.3311
# 1/1 [==============================] - 0s 75ms/step
# epoch:489  d_loss:0.1227  g_loss:3.3282
# 1/1 [==============================] - 0s 76ms/step
# epoch:490  d_loss:0.1479  g_loss:3.0350
# 1/1 [==============================] - 0s 78ms/step
# epoch:491  d_loss:0.2517  g_loss:2.3429
# 1/1 [==============================] - 0s 75ms/step
# epoch:492  d_loss:0.3811  g_loss:1.9491
# 1/1 [==============================] - 0s 77ms/step
# epoch:493  d_loss:0.2500  g_loss:3.1153
# 1/1 [==============================] - 0s 78ms/step
# epoch:494  d_loss:0.2842  g_loss:3.0356
# 1/1 [==============================] - 0s 78ms/step
# epoch:495  d_loss:0.3767  g_loss:2.7211
# 1/1 [==============================] - 0s 76ms/step
# epoch:496  d_loss:0.3306  g_loss:2.6560
# 1/1 [==============================] - 0s 76ms/step
# epoch:497  d_loss:0.3186  g_loss:2.0631
# 1/1 [==============================] - 0s 90ms/step
# epoch:498  d_loss:0.3885  g_loss:2.8588
# 1/1 [==============================] - 0s 79ms/step
# epoch:499  d_loss:0.1872  g_loss:3.2701
# 1/1 [==============================] - 0s 77ms/step
# epoch:500  d_loss:0.2356  g_loss:3.4507
# 1/1 [==============================] - 0s 78ms/step
# epoch:501  d_loss:0.1774  g_loss:3.4708
# 1/1 [==============================] - 0s 78ms/step
# epoch:502  d_loss:0.2683  g_loss:2.9332
# 1/1 [==============================] - 0s 136ms/step
# epoch:503  d_loss:0.1579  g_loss:3.4236
# 1/1 [==============================] - 0s 123ms/step
# epoch:504  d_loss:0.2399  g_loss:3.4296
# 1/1 [==============================] - 0s 134ms/step
# epoch:505  d_loss:0.3528  g_loss:3.2529
# 1/1 [==============================] - 0s 76ms/step
# epoch:506  d_loss:0.3477  g_loss:2.7724
# 1/1 [==============================] - 0s 81ms/step
# epoch:507  d_loss:0.5350  g_loss:2.1738
# 1/1 [==============================] - 0s 76ms/step
# epoch:508  d_loss:0.7062  g_loss:2.5644
# 1/1 [==============================] - 0s 79ms/step
# epoch:509  d_loss:0.2387  g_loss:3.2211
# 1/1 [==============================] - 0s 75ms/step
# epoch:510  d_loss:0.3791  g_loss:3.3887
# 1/1 [==============================] - 0s 76ms/step
# epoch:511  d_loss:0.3887  g_loss:3.4567
# 1/1 [==============================] - 0s 79ms/step
# epoch:512  d_loss:0.3916  g_loss:2.9288
# 1/1 [==============================] - 0s 79ms/step
# epoch:513  d_loss:0.4095  g_loss:2.5959
# 1/1 [==============================] - 0s 75ms/step
# epoch:514  d_loss:0.3578  g_loss:2.9983
# 1/1 [==============================] - 0s 74ms/step
# epoch:515  d_loss:0.2336  g_loss:3.2708
# 1/1 [==============================] - 0s 74ms/step
# epoch:516  d_loss:0.3564  g_loss:4.0274
# 1/1 [==============================] - 0s 76ms/step
# epoch:517  d_loss:0.3356  g_loss:3.5094
# 1/1 [==============================] - 0s 75ms/step
# ...
# epoch:1453  d_loss:0.4653  g_loss:2.2299
# 1/1 [==============================] - 0s 76ms/step
# epoch:1454  d_loss:0.5144  g_loss:1.9980
# 1/1 [==============================] - 0s 79ms/step
# epoch:1455  d_loss:0.3590  g_loss:1.8690
# 1/1 [==============================] - 0s 152ms/step
# epoch:1456  d_loss:0.5305  g_loss:1.4235
# 1/1 [==============================] - 0s 132ms/step
# epoch:1457  d_loss:0.5938  g_loss:1.9776
# 1/1 [==============================] - 0s 131ms/step
# epoch:1458  d_loss:0.4260  g_loss:2.1372
# 1/1 [==============================] - 0s 126ms/step
# epoch:1459  d_loss:0.5018  g_loss:1.7449
# 1/1 [==============================] - 0s 145ms/step
# epoch:1460  d_loss:0.6250  g_loss:1.5277
# 1/1 [==============================] - 0s 141ms/step
# epoch:1461  d_loss:0.4682  g_loss:1.7862
# 1/1 [==============================] - 0s 75ms/step
# epoch:1462  d_loss:0.6113  g_loss:1.7845
# 1/1 [==============================] - 0s 79ms/step
# epoch:1463  d_loss:0.3892  g_loss:1.7331
# 1/1 [==============================] - 0s 76ms/step
# epoch:1464  d_loss:0.5487  g_loss:1.5778
# 1/1 [==============================] - 0s 75ms/step
# epoch:1465  d_loss:0.5707  g_loss:1.6876
# 1/1 [==============================] - 0s 88ms/step
# epoch:1466  d_loss:0.6755  g_loss:1.4720
# 1/1 [==============================] - 0s 84ms/step
# epoch:1467  d_loss:0.3967  g_loss:1.5995
# 1/1 [==============================] - 0s 77ms/step
# epoch:1468  d_loss:0.5783  g_loss:1.2074
# 1/1 [==============================] - 0s 77ms/step
# epoch:1469  d_loss:0.5312  g_loss:1.2869
# 1/1 [==============================] - 0s 79ms/step
# epoch:1470  d_loss:0.4721  g_loss:1.6684
# 1/1 [==============================] - 0s 77ms/step
# epoch:1471  d_loss:0.4851  g_loss:1.7735
# 1/1 [==============================] - 0s 80ms/step
# epoch:1472  d_loss:0.4512  g_loss:2.0514
# 1/1 [==============================] - 0s 129ms/step
# epoch:1473  d_loss:0.4484  g_loss:1.7610
# 1/1 [==============================] - 0s 134ms/step
# epoch:1474  d_loss:0.4124  g_loss:1.8858
# 1/1 [==============================] - 0s 124ms/step
# epoch:1475  d_loss:0.4303  g_loss:1.8202
# 1/1 [==============================] - 0s 82ms/step
# epoch:1476  d_loss:0.3334  g_loss:1.7577
# 1/1 [==============================] - 0s 80ms/step
# epoch:1477  d_loss:0.3739  g_loss:1.3291
# 1/1 [==============================] - 0s 77ms/step
# epoch:1478  d_loss:0.4741  g_loss:1.4715
# 1/1 [==============================] - 0s 79ms/step
# epoch:1479  d_loss:0.3079  g_loss:1.7824
# 1/1 [==============================] - 0s 76ms/step
# epoch:1480  d_loss:0.4452  g_loss:2.0663
# 1/1 [==============================] - 0s 75ms/step
# epoch:1481  d_loss:0.5072  g_loss:1.9718
# 1/1 [==============================] - 0s 78ms/step
# epoch:1482  d_loss:0.4667  g_loss:1.7668
# 1/1 [==============================] - 0s 86ms/step
# epoch:1483  d_loss:0.3610  g_loss:1.8658
# 1/1 [==============================] - 0s 76ms/step
# epoch:1484  d_loss:0.3702  g_loss:1.7121
# 1/1 [==============================] - 0s 75ms/step
# epoch:1485  d_loss:0.3736  g_loss:1.8426
# 1/1 [==============================] - 0s 134ms/step
# epoch:1486  d_loss:0.4699  g_loss:1.7144
# 1/1 [==============================] - 0s 79ms/step
# epoch:1487  d_loss:0.5287  g_loss:1.9462
# 1/1 [==============================] - 0s 79ms/step
# epoch:1488  d_loss:0.4197  g_loss:1.8758
# 1/1 [==============================] - 0s 76ms/step
# epoch:1489  d_loss:0.6046  g_loss:1.6527
# 1/1 [==============================] - 0s 78ms/step
# epoch:1490  d_loss:0.4975  g_loss:1.5297
# 1/1 [==============================] - 0s 145ms/step
# epoch:1491  d_loss:0.4745  g_loss:1.9728
# 1/1 [==============================] - 0s 148ms/step
# epoch:1492  d_loss:0.5208  g_loss:1.8234
# 1/1 [==============================] - 0s 120ms/step
# epoch:1493  d_loss:0.5956  g_loss:1.8240
# 1/1 [==============================] - 0s 75ms/step
# epoch:1494  d_loss:0.4691  g_loss:1.9328
# 1/1 [==============================] - 0s 75ms/step
# epoch:1495  d_loss:0.4195  g_loss:2.1082
# 1/1 [==============================] - 0s 76ms/step
# epoch:1496  d_loss:0.6043  g_loss:1.4202
# 1/1 [==============================] - 0s 79ms/step
# epoch:1497  d_loss:0.6358  g_loss:1.3925
# 1/1 [==============================] - 0s 170ms/step
# epoch:1498  d_loss:0.5221  g_loss:1.2691
# 1/1 [==============================] - 0s 77ms/step
# epoch:1499  d_loss:0.3757  g_loss:1.5317
# 1/1 [==============================] - 0s 78ms/step
# epoch:1500  d_loss:0.4713  g_loss:1.8710
# 1/1 [==============================] - 0s 77ms/step
# epoch:1501  d_loss:0.5229  g_loss:2.0320
# 1/1 [==============================] - 0s 87ms/step
# epoch:1502  d_loss:0.3140  g_loss:2.5079
# 1/1 [==============================] - 0s 78ms/step
# epoch:1503  d_loss:0.4906  g_loss:1.8054
# 1/1 [==============================] - 0s 75ms/step
# epoch:1504  d_loss:0.3791  g_loss:1.7340
# 1/1 [==============================] - 0s 78ms/step
# epoch:1505  d_loss:0.4662  g_loss:1.5835
# 1/1 [==============================] - 0s 77ms/step
# epoch:1506  d_loss:0.4166  g_loss:1.6551
# 1/1 [==============================] - 0s 85ms/step
# epoch:1507  d_loss:0.3122  g_loss:1.5943
# 1/1 [==============================] - 0s 77ms/step
# epoch:1508  d_loss:0.3122  g_loss:1.8784
# 1/1 [==============================] - 0s 137ms/step
# epoch:1509  d_loss:0.4580  g_loss:2.2999
# 1/1 [==============================] - 0s 145ms/step
# epoch:1510  d_loss:0.4702  g_loss:2.3874
# 1/1 [==============================] - 0s 140ms/step
# epoch:1511  d_loss:0.4390  g_loss:2.1307
# 1/1 [==============================] - 0s 76ms/step
# epoch:1512  d_loss:0.4860  g_loss:2.1738
# 1/1 [==============================] - 0s 79ms/step
# epoch:1513  d_loss:0.4445  g_loss:1.9563
# 1/1 [==============================] - 0s 75ms/step
# epoch:1514  d_loss:0.3969  g_loss:1.8915
# 1/1 [==============================] - 0s 88ms/step
# epoch:1515  d_loss:0.4426  g_loss:1.3457
# 1/1 [==============================] - 0s 81ms/step
# epoch:1516  d_loss:0.4032  g_loss:2.0096
# 1/1 [==============================] - 0s 78ms/step
# epoch:1517  d_loss:0.3867  g_loss:2.3851
# 1/1 [==============================] - 0s 83ms/step
# epoch:1518  d_loss:0.3883  g_loss:1.6541
# 1/1 [==============================] - 0s 80ms/step
# epoch:1519  d_loss:0.4529  g_loss:1.7222
# 1/1 [==============================] - 0s 78ms/step
# epoch:1520  d_loss:0.5530  g_loss:1.2990
# 1/1 [==============================] - 0s 77ms/step
# epoch:1521  d_loss:0.3699  g_loss:2.0052
# 1/1 [==============================] - 0s 80ms/step
# epoch:1522  d_loss:0.4183  g_loss:1.9088
# 1/1 [==============================] - 0s 77ms/step
# epoch:1523  d_loss:0.2749  g_loss:1.8555
# 1/1 [==============================] - 0s 77ms/step
# epoch:1524  d_loss:0.3425  g_loss:2.1573
# 1/1 [==============================] - 0s 87ms/step
# epoch:1525  d_loss:0.3695  g_loss:2.0837
# 1/1 [==============================] - 0s 78ms/step
# epoch:1526  d_loss:0.3512  g_loss:2.8634
# 1/1 [==============================] - 0s 152ms/step
# epoch:1527  d_loss:0.5058  g_loss:2.4697
# 1/1 [==============================] - 0s 142ms/step
# epoch:1528  d_loss:0.4782  g_loss:2.3906
# 1/1 [==============================] - 0s 129ms/step
# epoch:1529  d_loss:0.4209  g_loss:2.1658
# 1/1 [==============================] - 0s 76ms/step
# epoch:1530  d_loss:0.5624  g_loss:1.9141
# 1/1 [==============================] - 0s 89ms/step
# epoch:1531  d_loss:0.3190  g_loss:2.1058
# 1/1 [==============================] - 0s 76ms/step
# epoch:1532  d_loss:0.4864  g_loss:1.6277
# 1/1 [==============================] - 0s 79ms/step
# epoch:1533  d_loss:0.3603  g_loss:1.8667
# 1/1 [==============================] - 0s 81ms/step
# epoch:1534  d_loss:0.5699  g_loss:1.6023
# 1/1 [==============================] - 0s 75ms/step
# epoch:1535  d_loss:0.3338  g_loss:1.8638
# 1/1 [==============================] - 0s 81ms/step
# epoch:1536  d_loss:0.5374  g_loss:1.9412
# 1/1 [==============================] - 0s 77ms/step
# epoch:1537  d_loss:0.4705  g_loss:2.1178
# 1/1 [==============================] - 0s 78ms/step
# epoch:1538  d_loss:0.4931  g_loss:2.0361
# 1/1 [==============================] - 0s 81ms/step
# epoch:1539  d_loss:0.4342  g_loss:2.0431
# 1/1 [==============================] - 0s 80ms/step
# epoch:1540  d_loss:0.4417  g_loss:1.6321
# 1/1 [==============================] - 0s 77ms/step
# epoch:1541  d_loss:0.4567  g_loss:1.6542
# 1/1 [==============================] - 0s 85ms/step
# epoch:1542  d_loss:0.5342  g_loss:1.7553
# 1/1 [==============================] - 0s 76ms/step
# epoch:1543  d_loss:0.5516  g_loss:1.8242
# 1/1 [==============================] - 0s 75ms/step
# epoch:1544  d_loss:0.3991  g_loss:1.7895
# 1/1 [==============================] - 0s 150ms/step
# epoch:1545  d_loss:0.5041  g_loss:1.5893
# 1/1 [==============================] - 0s 127ms/step
# epoch:1546  d_loss:0.4069  g_loss:1.8005
# 1/1 [==============================] - 0s 129ms/step
# epoch:1547  d_loss:0.4177  g_loss:1.8558
# 1/1 [==============================] - 0s 77ms/step
# epoch:1548  d_loss:0.3638  g_loss:2.0176
# 1/1 [==============================] - 0s 78ms/step
# epoch:1549  d_loss:0.2885  g_loss:1.9840
# 1/1 [==============================] - 0s 88ms/step
# epoch:1550  d_loss:0.4752  g_loss:1.8764
# 1/1 [==============================] - 0s 78ms/step
# epoch:1551  d_loss:0.3270  g_loss:2.2364
# 1/1 [==============================] - 0s 76ms/step
# epoch:1552  d_loss:0.4023  g_loss:2.0425
# 1/1 [==============================] - 0s 76ms/step
# epoch:1553  d_loss:0.4176  g_loss:2.0293
# 1/1 [==============================] - 0s 79ms/step
# epoch:1554  d_loss:0.4524  g_loss:1.4024
# 1/1 [==============================] - 0s 89ms/step
# epoch:1555  d_loss:0.4070  g_loss:1.5570
# 1/1 [==============================] - 0s 82ms/step
# epoch:1556  d_loss:0.4141  g_loss:1.7310
# 1/1 [==============================] - 0s 82ms/step
# epoch:1557  d_loss:0.5162  g_loss:1.7254
# 1/1 [==============================] - 0s 76ms/step
# epoch:1558  d_loss:0.4532  g_loss:2.1677
# 1/1 [==============================] - 0s 80ms/step
# epoch:1559  d_loss:0.5657  g_loss:1.8082
# 1/1 [==============================] - 0s 76ms/step
# epoch:1560  d_loss:0.4976  g_loss:1.4324
# 1/1 [==============================] - 0s 81ms/step
# epoch:1561  d_loss:0.4239  g_loss:1.4763
# 1/1 [==============================] - 0s 81ms/step
# epoch:1562  d_loss:0.3787  g_loss:2.0861
# 1/1 [==============================] - 0s 100ms/step
# epoch:1563  d_loss:0.4109  g_loss:1.9015
# 1/1 [==============================] - 0s 137ms/step
# epoch:1564  d_loss:0.5845  g_loss:1.5615
# 1/1 [==============================] - 0s 136ms/step
# epoch:1565  d_loss:0.6569  g_loss:1.4376
# 1/1 [==============================] - 0s 75ms/step
# epoch:1566  d_loss:0.5444  g_loss:1.3634
# 1/1 [==============================] - 0s 75ms/step
# epoch:1567  d_loss:0.4070  g_loss:1.4260
# 1/1 [==============================] - 0s 81ms/step
# epoch:1568  d_loss:0.4748  g_loss:1.4939
# 1/1 [==============================] - 0s 77ms/step
# epoch:1569  d_loss:0.5184  g_loss:1.3780
# 1/1 [==============================] - 0s 76ms/step
# epoch:1570  d_loss:0.5337  g_loss:1.7266
# 1/1 [==============================] - 0s 76ms/step
# epoch:1571  d_loss:0.3869  g_loss:2.2384
# 1/1 [==============================] - 0s 79ms/step
# epoch:1572  d_loss:0.5785  g_loss:1.4736
# 1/1 [==============================] - 0s 80ms/step
# epoch:1573  d_loss:0.5346  g_loss:1.6015
# 1/1 [==============================] - 0s 76ms/step
# epoch:1574  d_loss:0.4848  g_loss:1.0864
# 1/1 [==============================] - 0s 75ms/step
# epoch:1575  d_loss:0.4855  g_loss:1.3769
# 1/1 [==============================] - 0s 88ms/step
# epoch:1576  d_loss:0.4050  g_loss:1.9123
# 1/1 [==============================] - 0s 78ms/step
# epoch:1577  d_loss:0.4347  g_loss:2.3773
# 1/1 [==============================] - 0s 76ms/step
# epoch:1578  d_loss:0.5323  g_loss:2.0341
# 1/1 [==============================] - 0s 78ms/step
# epoch:1579  d_loss:0.4914  g_loss:1.7263
# 1/1 [==============================] - 0s 76ms/step
# epoch:1580  d_loss:0.4579  g_loss:1.7016
# 1/1 [==============================] - 0s 77ms/step
# epoch:1581  d_loss:0.5594  g_loss:1.4361
# 1/1 [==============================] - 0s 150ms/step
# epoch:1582  d_loss:0.4198  g_loss:1.8565
# 1/1 [==============================] - 0s 119ms/step
# epoch:1583  d_loss:0.4185  g_loss:1.4923
# 1/1 [==============================] - 0s 138ms/step
# epoch:1584  d_loss:0.4157  g_loss:2.1099
# 1/1 [==============================] - 0s 79ms/step
# epoch:1585  d_loss:0.4513  g_loss:2.0494
# 1/1 [==============================] - 0s 76ms/step
# epoch:1586  d_loss:0.3932  g_loss:1.9152
# 1/1 [==============================] - 0s 81ms/step
# epoch:1587  d_loss:0.3186  g_loss:2.0620
# 1/1 [==============================] - 0s 79ms/step
# epoch:1588  d_loss:0.3831  g_loss:1.9054
# 1/1 [==============================] - 0s 80ms/step
# epoch:1589  d_loss:0.4418  g_loss:1.9141
# 1/1 [==============================] - 0s 79ms/step
# epoch:1590  d_loss:0.3928  g_loss:1.9301
# 1/1 [==============================] - 0s 75ms/step
# epoch:1591  d_loss:0.3729  g_loss:2.0684
# 1/1 [==============================] - 0s 81ms/step
# epoch:1592  d_loss:0.3457  g_loss:2.3739
# 1/1 [==============================] - 0s 78ms/step
# epoch:1593  d_loss:0.3089  g_loss:2.4135
# 1/1 [==============================] - 0s 75ms/step
# epoch:1594  d_loss:0.3879  g_loss:2.6630
# 1/1 [==============================] - 0s 75ms/step
# epoch:1595  d_loss:0.3729  g_loss:1.9397
# 1/1 [==============================] - 0s 80ms/step
# epoch:1596  d_loss:0.3913  g_loss:1.6673
# 1/1 [==============================] - 0s 77ms/step
# epoch:1597  d_loss:0.5005  g_loss:1.8247
# 1/1 [==============================] - 0s 80ms/step
# epoch:1598  d_loss:0.4046  g_loss:1.7212
# 1/1 [==============================] - 0s 79ms/step
# epoch:1599  d_loss:0.3689  g_loss:2.0262
# 1/1 [==============================] - 0s 124ms/step
# epoch:1600  d_loss:0.3828  g_loss:2.6349
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 80ms/step
# epoch:1601  d_loss:0.4487  g_loss:2.2386
# 1/1 [==============================] - 0s 84ms/step
# epoch:1602  d_loss:0.4227  g_loss:1.8305
# 1/1 [==============================] - 0s 76ms/step
# epoch:1603  d_loss:0.6559  g_loss:1.6173
# 1/1 [==============================] - 0s 80ms/step
# epoch:1604  d_loss:0.5390  g_loss:1.5469
# 1/1 [==============================] - 0s 104ms/step
# epoch:1605  d_loss:0.3977  g_loss:1.6313
# 1/1 [==============================] - 0s 76ms/step
# epoch:1606  d_loss:0.5332  g_loss:1.8896
# 1/1 [==============================] - 0s 83ms/step
# epoch:1607  d_loss:0.4521  g_loss:1.7942
# 1/1 [==============================] - 0s 80ms/step
# epoch:1608  d_loss:0.5357  g_loss:1.9295
# 1/1 [==============================] - 0s 80ms/step
# epoch:1609  d_loss:0.6279  g_loss:1.6913
# 1/1 [==============================] - 0s 78ms/step
# epoch:1610  d_loss:0.4974  g_loss:1.3360
# 1/1 [==============================] - 0s 79ms/step
# epoch:1611  d_loss:0.5181  g_loss:1.3887
# 1/1 [==============================] - 0s 78ms/step
# epoch:1612  d_loss:0.7182  g_loss:1.9734
# 1/1 [==============================] - 0s 79ms/step
# epoch:1613  d_loss:0.5477  g_loss:1.7725
# 1/1 [==============================] - 0s 80ms/step
# epoch:1614  d_loss:0.6658  g_loss:1.8468
# 1/1 [==============================] - 0s 80ms/step
# epoch:1615  d_loss:0.7402  g_loss:1.4702
# 1/1 [==============================] - 0s 144ms/step
# epoch:1616  d_loss:0.5910  g_loss:1.3587
# 1/1 [==============================] - 0s 155ms/step
# epoch:1617  d_loss:0.5559  g_loss:1.4742
# 1/1 [==============================] - 0s 156ms/step
# epoch:1618  d_loss:0.5968  g_loss:1.3469
# 1/1 [==============================] - 0s 81ms/step
# epoch:1619  d_loss:0.5375  g_loss:1.5078
# 1/1 [==============================] - 0s 81ms/step
# epoch:1620  d_loss:0.4100  g_loss:1.6320
# 1/1 [==============================] - 0s 91ms/step
# epoch:1621  d_loss:0.4379  g_loss:1.8618
# 1/1 [==============================] - 0s 81ms/step
# epoch:1622  d_loss:0.4108  g_loss:1.4797
# 1/1 [==============================] - 0s 83ms/step
# epoch:1623  d_loss:0.5482  g_loss:1.6917
# 1/1 [==============================] - 0s 81ms/step

# %% [markdown]
# ## 4. 이미지의 특징을 추출하는 오토인코더
#
# 오토인코더는 GAN 과 비슷한 결과를 만들지만, 다른 성징을 지니고 있음
#
# GAN 이 세상에 존재하지 않는 완전한 가상의 것을 만들어 내는 반면에, 오토인코더는 입력 데이터의 특징을 효율적으로 담아낸 이미지를 만들어 냄
#
# 오토인코더는 어디에 활용할 수 있을지?
#
# - 영상 의학 분야 등 아직 데이터 수가 충분하지 않은 분야
#
# 학습 데이터는 현실 세계의 정보를 담고 있어야 하므로, 세상에 존재하지 않는 가상의 것을 집어넣으면 예상치 못한 결과를 가져올 수 있는데, 데이터의 특징을 잘 담아내는 오토 인코더라면 다름
#
# 부족한 학습 데이터 수를 효과적으로 늘려 주는 효과를 기대할 수 있음

# %%
# MNIST 데이터셋을 불러옵니다.

(X_train, _), (X_test, _) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32') / 255
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32') / 255

# 생성자 모델을 만듭니다.
autoencoder = Sequential()

# 인코딩 부분입니다.
autoencoder.add(Conv2D(16, kernel_size=3, padding='same', input_shape=(28,28,1), activation='relu'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, activation='relu', padding='same'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, strides=2, padding='same', activation='relu'))

# 디코딩 부분입니다.
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(16, kernel_size=3, activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(1, kernel_size=3, padding='same', activation='sigmoid'))

# 전체 구조를 확인합니다.
autoencoder.summary()

# %%
# 컴파일 및 학습을 하는 부분입니다.
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.fit(X_train, X_train, epochs=50, batch_size=128, validation_data=(X_test, X_test))

# 학습된 결과를 출력하는 부분입니다.
random_test = np.random.randint(X_test.shape[0], size=5)  # 테스트할 이미지를 랜덤하게 불러옵니다.
ae_imgs = autoencoder.predict(X_test)                     # 앞서 만든 오토인코더 모델에 집어 넣습니다.

plt.figure(figsize=(7, 2))                         # 출력될 이미지의 크기를 정합니다.

for i, image_idx in enumerate(random_test):        # 랜덤하게 뽑은 이미지를 차례로 나열합니다.
   ax = plt.subplot(2, 7, i + 1)
   plt.imshow(X_test[image_idx].reshape(28, 28))   # 테스트할 이미지를 먼저 그대로 보여줍니다.
   ax.axis('off')
   ax = plt.subplot(2, 7, 7 + i +1)
   plt.imshow(ae_imgs[image_idx].reshape(28, 28))  # 오토인코딩 결과를 다음열에 출력합니다.
   ax.axis('off')
plt.show()
