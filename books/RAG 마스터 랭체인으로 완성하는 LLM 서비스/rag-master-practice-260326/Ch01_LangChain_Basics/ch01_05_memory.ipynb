# %%
from dotenv import load_dotenv

load_dotenv("../.env")
# Out:
# True

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

chat = ChatOpenAI(model="gpt-4o-mini")

prompt = ChatPromptTemplate.from_messages([
    ("system", "당신은 금융 상답사입니다. 사용자에게 최선의 금융 조언을 제공합니다."),
    ("placeholder", "{messages}")
])

chain = prompt | chat

ai_msg = chain.invoke({
    "messages": [
        ("human", "저축을 늘리기 위해 무엇을 할 수 있나요?"),  # 사용자의 첫 질문
        ("ai", "저축 목표를 설정하고, 매달 자동 이체로 일정 금액을 저축하세요."),  # 챗봇의 답변
        ("human", "방금 뭐라고 했나요?"),  # 사용자의 재확인 질문
    ]
})

print(ai_msg.content)
# Out:
# 저축을 늘리기 위해 다음과 같은 방법을 제안했습니다:
#
# 1. **저축 목표 설정**: 구체적인 목표를 정하면 저축 motivation이 높아집니다.
# 2. **자동 이체 활용**: 매달 정해진 금액을 자동으로 저축 계좌로 이체하도록 설정하여 저축을 습관화하세요.
#
# 이 외에도 예산을 세우고 불필요한 지출을 줄이는 것도 도움이 됩니다. 필요하다면 추가 조언을 드릴 수 있으니 말씀해 주세요!

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_community.chat_message_histories import ChatMessageHistory

prompt = ChatPromptTemplate.from_messages([
    ("system", "당신은 금융 상담사입니다. 모든 질문에 최선을 다해 답변하십시오."),
    ("placeholder", "{chat_history}"),  # 이전 대화 이력
    ("human", "{input}"),  # 사용자의 새로운 질문
])

chat_history = ChatMessageHistory()
chain = prompt | chat

chain_with_message_history = RunnableWithMessageHistory(
    chain,
    lambda session_id: chat_history,
    input_messages_key="input",
    history_messages_key="chat_history",
)

chain_with_message_history.invoke(
    {"input": "저축을 늘리기 위해 무엇을 할 수 있나요?"},
    {"configurable": {"session_id": "unused"}}
).content
# Out:
# '저축을 늘리기 위해 여러 가지 방법을 고려할 수 있습니다. 여기 몇 가지 제안을 드립니다:\n\n1. **예산 수립**: 수입과 지출을 명확히 파악하고, 월별 예산을 작성하세요. 이를 통해 불필요한 지출을 줄일 수 있습니다.\n\n2. **저축 목표 설정**: 단기 및 장기 저축 목표를 설정하세요. 예를 들어, 여행, 결혼, 집 마련 등의 구체적인 목표를 통해 저축의 동기를 부여할 수 있습니다.\n\n3. **자동 이체 설정**: 급여가 들어오는 날에 일정 금액을 자동으로 저축 계좌로 이체되도록 설정하세요. 이렇게 하면 저축을 잊지 않고 자연스레 저축할 수 있습니다.\n\n4. **비상 자금 마련**: 예상치 못한 지출을 대비해 비상 자금을 마련하세요. 이 자금이 있다면 더 이상의 불필요한 대출이나 소비를 피할 수 있습니다.\n\n5. **불필요한 지출 줄이기**: 구독 서비스나 외식, 쇼핑 등에서 줄일 수 있는 항목들을 찾아보세요. 필요한 지출과 원하지 않는 지출을 구분하여 필요한 것만 남기는 것이 좋습니다.\n\n6. **수익성 높은 저축 계좌 선택**: 고이율의 저축 계좌나 정기예금을 찾아보세요. 이러한 계좌들은 더 높은 이자를 제공하여 돈이 더 빨리 불어날 수 있습니다.\n\n7. **부업 고려**: 추가적인 수입원을 만들어 저축을 늘리는 것도 좋은 방법입니다. 자신의 기술이나 취미를 활용해 프리랜서로 일하거나 창업을 고려해 보세요.\n\n8. **소비 패턴 분석**: 월별 지출 내역을 분석하여 어떤 항목에서 지출이 많은지 파악하고, 그에 맞춰 소비 패턴을 조정하세요.\n\n9. **할인 및 쿠폰 활용**: 쇼핑할 때 할인이나 쿠폰을 활용하여 비용을 절감하세요. 이렇게 절감된 금액을 저축에 활용할 수 있습니다.\n\n10. **금융 교육**: 금융 관련 서적이나 강의를 통해 재정 지식을 늘리세요. 올바른 금융 관리 방법을 알게 되면 저축이 더 쉬워질 수 있습니다.\n\n이런 방법들을 통해 꾸준히 저축을 늘릴 수 있을 것입니다. 중요한 것은 일관성과 계획이니, 자신만의 저축 습관을 만들어 나가는 것이 중요합니다.'

# %%
chain_with_message_history.invoke(
    {"input": "내가 방금 뭐라고 했나요?"},  # 사용자의 질문
    {"configurable": {"session_id": "unused"}}  # 세션 ID 설정
).content
# Out:
# '당신은 "저축을 늘리기 위해 무엇을 할 수 있나요?"라고 질문하셨습니다. 이 질문에 대해 다양한 저축 방법을 제안드렸습니다. 더 궁금한 점이나 추가 질문이 있으시다면 말씀해 주세요!'

# %%
chat_history
# Out:
# InMemoryChatMessageHistory(messages=[HumanMessage(content='저축을 늘리기 위해 무엇을 할 수 있나요?', additional_kwargs={}, response_metadata={}), AIMessage(content='저축을 늘리기 위해 여러 가지 방법을 고려할 수 있습니다. 여기 몇 가지 제안을 드립니다:\n\n1. **예산 수립**: 수입과 지출을 명확히 파악하고, 월별 예산을 작성하세요. 이를 통해 불필요한 지출을 줄일 수 있습니다.\n\n2. **저축 목표 설정**: 단기 및 장기 저축 목표를 설정하세요. 예를 들어, 여행, 결혼, 집 마련 등의 구체적인 목표를 통해 저축의 동기를 부여할 수 있습니다.\n\n3. **자동 이체 설정**: 급여가 들어오는 날에 일정 금액을 자동으로 저축 계좌로 이체되도록 설정하세요. 이렇게 하면 저축을 잊지 않고 자연스레 저축할 수 있습니다.\n\n4. **비상 자금 마련**: 예상치 못한 지출을 대비해 비상 자금을 마련하세요. 이 자금이 있다면 더 이상의 불필요한 대출이나 소비를 피할 수 있습니다.\n\n5. **불필요한 지출 줄이기**: 구독 서비스나 외식, 쇼핑 등에서 줄일 수 있는 항목들을 찾아보세요. 필요한 지출과 원하지 않는 지출을 구분하여 필요한 것만 남기는 것이 좋습니다.\n\n6. **수익성 높은 저축 계좌 선택**: 고이율의 저축 계좌나 정기예금을 찾아보세요. 이러한 계좌들은 더 높은 이자를 제공하여 돈이 더 빨리 불어날 수 있습니다.\n\n7. **부업 고려**: 추가적인 수입원을 만들어 저축을 늘리는 것도 좋은 방법입니다. 자신의 기술이나 취미를 활용해 프리랜서로 일하거나 창업을 고려해 보세요.\n\n8. **소비 패턴 분석**: 월별 지출 내역을 분석하여 어떤 항목에서 지출이 많은지 파악하고, 그에 맞춰 소비 패턴을 조정하세요.\n\n9. **할인 및 쿠폰 활용**: 쇼핑할 때 할인이나 쿠폰을 활용하여 비용을 절감하세요. 이렇게 절감된 금액을 저축에 활용할 수 있습니다.\n\n10. **금융 교육**: 금융 관련 서적이나 강의를 통해 재정 지식을 늘리세요. 올바른 금융 관리 방법을 알게 되면 저축이 더 쉬워질 수 있습니다.\n\n이런 방법들을 통해 꾸준히 저축을 늘릴 수 있을 것입니다. 중요한 것은 일관성과 계획이니, 자신만의 저축 습관을 만들어 나가는 것이 중요합니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 549, 'prompt_tokens': 44, 'total_tokens': 593, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_e738e3044b', 'id': 'chatcmpl-DOsplsrUMoJ8crBQdbOsdKJweuAhQ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d3bb2-2ad7-7d00-9c7f-42e7de09c7c8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 549, 'total_tokens': 593, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='내가 방금 뭐라고 했나요?', additional_kwargs={}, response_metadata={}), AIMessage(content='당신은 "저축을 늘리기 위해 무엇을 할 수 있나요?"라고 질문하셨습니다. 이 질문에 대해 다양한 저축 방법을 제안드렸습니다. 더 궁금한 점이나 추가 질문이 있으시다면 말씀해 주세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 610, 'total_tokens': 665, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_37b32d27ed', 'id': 'chatcmpl-DOsqAjFMUnirCwV0yKyCTnbEiYdiV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d3bb2-8d87-7be3-a657-24c81737f074-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 610, 'output_tokens': 55, 'total_tokens': 665, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})])

# %%
from langchain_core.messages import trim_messages
from langchain_core.runnables import RunnablePassthrough
from operator import itemgetter

trimmer = trim_messages(strategy="last", max_tokens=2, token_counter=len)
chain_with_trimming = (
    RunnablePassthrough.assign(chat_history=itemgetter("chat_history") | trimmer)
    | prompt
    | chat
)

chain_with_trimmed_history = RunnableWithMessageHistory(
    chain_with_trimming,
    lambda session_id: chat_history,
    input_messages_key="input",
    history_messages_key="chat_history",
)

chain_with_trimmed_history.invoke(
    {"input": "저는 5년 내에 집을 사기 위해 어떤 재정 계획을 세워야 하나요?"},  # 사용자의 질문
    {"configurable": {"session_id": "finance_session_1"}}  # 세션 ID 설정
)
# Out:
# AIMessage(content='5년 내에 집을 사기 위한 재정 계획을 세우는 것은 중요한 결정입니다. 다음은 몇 가지 단계와 팁입니다:\n\n1. **목표 설정하기**:\n   - 구매하고 싶은 집의 예산을 정하세요. 지역에 따라 가격이 크게 다를 수 있습니다.\n\n2. **예산 분석**:\n   - 현재 소득과 지출을 분석하여 매달 얼마를 저축할 수 있는지 파악하세요.\n   - 필요한 생활비를 고려한 후, 저축 가능한 금액을 세워보세요.\n\n3. **저축 목표 설정**:\n   - 집 구매를 위해 필요한 초기 자본(다운 페이먼트)을 정하세요. 일반적으로 20% 정도가 권장되지만, 지역에 따라 달라질 수 있습니다.\n   - 예를 들어, 3억 원짜리 집을 살 경우, 20%인 6천만 원을 목표로 할 수 있습니다.\n\n4. **저축 계좌 개설**:\n   - 별도의 저축 계좌를 만들어 정기적으로 저축하는 습관을 들이세요. 높은 이자율을 제공하는 계좌를 선택하는 것도 좋습니다.\n\n5. **투자 고려하기**:\n   - 저축 외에도 안정적인 투자 상품을 고려해 보세요. 예를 들어, 적립식 펀드나 ETF와 같은 투자로 자산을 늘릴 수 있습니다. 다만, 투자에는 리스크가 있으므로 신중해야 합니다.\n\n6. **신용 점수 관리**:\n   - 집을 구매하기 위해서는 대출이 필요할 경우가 많으므로 신용 점수를 관리하는 것이 중요합니다. 정기적인 납부 및 부채 관리로 점수를 높일 수 있습니다.\n\n7. **부동산 시장 조사**:\n   - 주택 시장에 대한 정보를 지속적으로 수집하고, 가격과 트렌드를 파악하세요. 이를 통해 적절한 시점에 구매할 수 있습니다.\n\n8. **전문가 상담**:\n   - 필요하다면 금융 상담사나 부동산 전문가와 상의하여 더욱 구체적이고 실행 가능한 계획을 세울 수 있습니다.\n\n이러한 단계들을 통해 5년 내에 원하는 집을 구매하기 위한 목표 달성이 가능할 것입니다. 추가적인 질문이나 도움이 필요하시면 언제든지 말씀해 주세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 496, 'prompt_tokens': 125, 'total_tokens': 621, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_42c260b709', 'id': 'chatcmpl-DOsyCMoukJ9freoYqcs9txrOCBOCn', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d3bba-1fbb-7183-9461-1565499b46d1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 125, 'output_tokens': 496, 'total_tokens': 621, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
chain_with_trimmed_history.invoke(
    {"input": "내가 방금 뭐라고 했나요?"},
    {"configurable": {"session_id": "finance_session_1"}}
).content
# Out:
# '당신은 "저는 5년 내에 집을 사기 위해 어떤 재정 계획을 세워야 하나요?"라고 질문하셨습니다. 집을 구매하기 위한 재정 계획을 세우는 방법에 대해 여러 가지 조언을 제공해 드렸습니다. 추가로 궁금한 점이 있으시면 말씀해 주세요!'

# %%
def summarize_messages(chat_input: ChatMessageHistory) -> bool:
    stored_messages = chat_history.messages
    if len(stored_messages) == 0:
        return False

    summarization_prompt = ChatPromptTemplate.from_messages([
        ("placeholder", "{chat_history}"),
        (
            "user",
            "이전 대화를 요약해 주세요. 가능한 한 많은 세부 정보를 포함하십시오.",
        ),
    ])

    summarization_chain = summarization_prompt | chat
    summary_message = summarization_chain.invoke({"chat_history": stored_messages})
    chat_history.clear()
    chat_history.add_message(summary_message)
    return True

# %%
chain_with_summarization = (
    RunnablePassthrough.assign(messages_summarized=summarize_messages)
    | chain_with_message_history
)

print(chain_with_summarization.invoke(
    {"input": "저에게 어떤 재정적 조언을 해주셨나요?"},
    {"configurable": {"session_id": "unused"}}
).content)
# Out:
# 당신의 재정 상황에 맞는 조언은 가능하면 구체적인 질문이나 목표에 따라 달라질 수 있습니다. 하지만 일반적인 재정 조언으로는 다음과 같은 내용을 포함할 수 있습니다:
#
# 1. **예산 수립**: 월별 수입과 지출을 파악하고, 예산을 세워 지출을 관리하는 것이 중요합니다. 이를 통해 낭비를 줄이고 저축을 늘릴 수 있습니다.
#
# 2. **저축 목표 설정**: 단기 및 장기 저축 목표를 명확히 하세요. 예를 들어, 비상금 마련, 여행, 집 구매 등을 목표로 설정할 수 있습니다.
#
# 3. **저축 자동화**: 급여가 들어오는 즉시 일정 금액을 저축 계좌로 자동 이체하는 방법은 저축 습관을 만드는 데 효과적입니다.
#
# 4. **비상 자금 준비**: 3~6개월의 생활비를 비상 자금으로 마련해두면 예기치 못한 상황에 대비할 수 있습니다.
#
# 5. **불필요한 지출 줄이기**: 지출 내역을 분석하고, 혜택이 적은 소비를 줄이는 노력이 필요합니다. 예를 들어, 정기 구독 서비스나 불필요한 지출을 줄이는 것이 좋은 방법입니다.
#
# 6. **금융 상품 비교**: 저축 계좌, 투자 상품, 대출 상품 등을 비교하여 가장 유리한 조건을 선택하는 것이 중요합니다.
#
# 7. **부업이나 추가 수입원 고려**: 정규 소득 외에 추가적인 수입원을 만들어 재정적 여유를 늘리는 것도 좋은 전략입니다.
#
# 8. **신용 점수 관리**: 좋은 신용 점수는 대출을 받을 때 유리합니다. 정기적으로 신용 점수를 확인하고 관리하세요.
#
# 9. **재정 교육**: 다양한 금융 관련 자원을 활용하여 금융 지식을 늘리는 것이 도움이 됩니다. 책, 온라인 코스, 세미나 등을 통해 배울 수 있습니다.
#
# 10. **전문가 상담**: 필요하다면 재정 상담사와 상담하여 개인 맞춤형 조언을 받는 것도 좋은 방법입니다.
#
# 이와 같은 조언들이 특히 필요하거나 구체적으로 도움을 원하는 분야가 있다면 말씀해 주세요. 더 구체적인 전략이나 정보를 제공해 드리겠습니다!
