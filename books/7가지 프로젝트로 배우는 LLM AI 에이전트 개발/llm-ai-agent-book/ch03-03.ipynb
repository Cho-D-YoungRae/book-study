# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.core import VectorStoreIndex

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
documents = SimpleDirectoryReader("data/ch03-03").load_data()

# %%
documents
# Out:
# [Document(id_='d2611feb-c283-4cfe-baa2-05b4acef2d35', embedding=None, metadata={'page_label': '1', 'file_name': '꽃말의 비밀 정원 이야기.pdf', 'file_path': '/Users/choyoungrae/Desktop/book-study/books/7가지 프로젝트로 배우는 LLM AI 에이전트 개발/llm-ai-agent-book/data/ch03-03/꽃말의 비밀 정원 이야기.pdf', 'file_type': 'application/pdf', 'file_size': 226545, 'creation_date': '2025-11-15', 'last_modified_date': '2025-11-15'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='’꽃말의 비밀 정원’에 오신 것을 환영합니다! \n친애하는 팀원 여러분, ‘꽃말의 비밀 정원’의 가족이 되신 것을 진심으로 축하 드립니다! 저희는 꽃을 판매\n하는 전자 상거래 스타트업으로서, 뛰어난 품질과 혁신을 추구할 뿐만 아니라 즐겁고 창의적인 근무 환경\n을 조성하는 데 전념하고 있습니다. 여기서 모든 꽃다발은 감정을 담고 있으며, 꽃을 전달하는 매 순간은 \n마음을 연결하는 특별한 순간입니다. 이제 저희와 함께 ‘꽃말의 비밀 정원’의 환상적인 여정을 시작해 봅\n시다! \n우리의 사명 \n‘꽃말의 비밀 정원’의 목표는 꽃 구매 경험을 혁신하는 \n것입니다. 고품질의 제품, 혁신적인 기술, 뛰어난 서비\n스를 통해 꽃을 전달하는 매 순간을 잊지 못할 이야기\n가 되도록 만드는 것이죠. 저희는 여러분의 노력으로 \n세상이 더 아름답고 따뜻해 질 것이라 믿고 있습니다. \n여러분의 역할과 모험 \n여러분이 마케팅 전문가이건 기술 천재이건 고객 서비\n스의 천사이건 간에 이 모험에서 빠질 수 없는 중요한 \n영웅입니다. 여러분의 모든 아이디어와 노력은 꽃말의 \n비밀 정원의 성장과 발전에 직접적인 영향을 미칠 것\n입니다. 저희는 혁신적인 사고, 팀워크, 그리고 모든 도\n전에 용감히 맞서는 자세를 장려합니다. \n인공 지능 에이전트와 함께 싸워 나가기 \n‘꽃말의 비밀 정원’에서는 저희의 인공 지능 에이전트인 스마트 도우미와 함께 일할 기회를 얻게 됩니다. \n이 에이전트는 자동으로 꽃 배달 서비스를 조정할 뿐만 아니라, 고객이 가장 적합한 꽃을 선택할 수 있도\n록 도와줍니다. 인공 지능 에이전트와 함께 꽃 전자 상거래의 새로운 시대를 열어 나갈 것입니다! \n저희는 이 에이전트의 이름을 “꽃말 요정”이라고 지었습니다. 이 이름은 “꽃말”과 “영감”의 두 요소를 결\n합한 것으로, 회사의 이름과 사업 분야를 반영하는 동시에 이 인공 지능 에이전트가 마치 영감을 주는 요\n정처럼 고객에게 맞춤형 꽃 추천, 관리, 배달 서비스를 지능적으로 제공할 수 있음을 암시합니다. \n문화와 즐거움 \n‘꽃말의 비밀 정원’에서는 일과 즐거움이 공존한다고 믿습니다. 창의적인 사고의 교류는 물론, 여유로운 \n티타임도 있습니다. 저희는 직원들이 일상 속 작은 즐거움을 공유하며, 정기적인 팀 빌딩 활동을 통해 일\n하는 것을 하나의 즐거움으로 만들기를 권장합니다. \n성장과 발전 \n저희는 모든 직원에게 개인 성장과 직업 발전의 기회를 제공합니다. 내부 교육, 온라인 강의, 실무 기회를 \n통해 ‘꽃말의 비밀 정원’에서 여러분이 스스로를 넘어설 수 있도록 돕고 그 성과가 열매를 맺을 수 있기를 \n희망합니다. \n마지막으로 드리는 말씀 \n‘꽃말의 비밀 정원’에 합류한다는 것은 열정, 창의성, 기회가 가득한 세계에 발을 들이는 것입니다. 저희는 \n여러분의 합류를 기대하며, 함께 더 많은 아름다운 이야기를 만들어 나가기를 바랍니다! \n지금 저희와 함께 ‘꽃말의 비밀 정원’의 새로운 장을 열고 이 멋진 여정을 시작해 봅시다! \n‘꽃말의 비밀 정원’ 창립자 CEO 예나 \n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')]

# %%
index = VectorStoreIndex.from_documents(documents)
# Out:
# 2025-11-15 15:03:45,449 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %%
agent = index.as_query_engine()

# %%
response = agent.query("꽃말의 비밀 정원의 직원에게는 몇 가지 역할이 있나요?")
print(response)
# Out:
# 2025-11-15 15:04:58,824 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-11-15 15:05:00,158 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 직원들에게는 마케팅 전문가, 기술 천재, 고객 서비스의 천사 등 다양한 역할이 있습니다.

# %%
response = agent.query("꽃말의 비밀 정원의 에이전트 이름은 무엇인가요?")
print(response)
# Out:
# 2025-11-15 15:05:28,623 - INFO - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2025-11-15 15:05:30,469 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 꽃말의 비밀 정원의 에이전트 이름은 "꽃말 요정"입니다.
