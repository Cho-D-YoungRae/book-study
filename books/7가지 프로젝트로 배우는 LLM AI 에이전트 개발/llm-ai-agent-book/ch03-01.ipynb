# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
prompt = ChatPromptTemplate.from_template("{topic}에 대한 이야기를 들려주세요. 한글로 대답해 주세요.")
model = ChatOpenAI(model="gpt-4o")
output_parser = StrOutputParser()

chain = prompt | model | output_parser

# %%
message = chain.invoke({"topic": "수선화"})
print(message)
# Out:
# 수선화는 백합과에 속하는 여러해살이 구근 식물로, 학명은 Narcissus입니다. 주로 유럽과 북아프리카, 지중해 지역에서 자생하며, 봄에 아름다운 꽃을 피웁니다. 수선화는 대개 노란색이나 흰색 꽃을 피우며, 트럼펫 모양의 꽃부리가 특징적입니다.
#
# 수선화는 서양에서는 'Daffodil'이라고 불리기도 하며, 특히 영국 웨일스 지방의 상징 꽃입니다. 수선화는 봄을 알리는 꽃으로 여겨지며, 봄철 정원이나 공원에서 흔히 볼 수 있습니다. 또한, 수선화는 재배가 비교적 쉬워 정원 가꾸기 초보자에게도 인기가 많습니다.
#
# 수선화에 얽힌 전설 중 하나로는, 그리스 신화에 나오는 나르키소스(Narcissus)의 이야기가 유명합니다. 나르키소스는 자신의 아름다움에 도취되어 연못에 비친 자신의 모습에 반해 결국 물에 빠져 죽게 되는데, 그가 쓰러진 자리에서 피어난 꽃이 바로 수선화라고 합니다. 이 이야기에서 수선화는 자기애와 관련된 상징으로 여겨지기도 합니다.
#
# 오늘날 수선화는 보는 사람에게 기쁨과 희망을 주는 꽃으로 사랑받고 있으며, 생일, 기념일, 각종 축하 행사에 자주 사용됩니다. 또한, 일부 문화에서는 부활과 새로운 시작을 상징하기도 합니다.
